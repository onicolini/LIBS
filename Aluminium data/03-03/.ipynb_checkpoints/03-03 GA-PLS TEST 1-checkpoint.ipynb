# %% [markdown]
# ## Intensity filtered data using reference aluminium wavelength 309.506 (pixel number 445) using saturated data

# %%
import os
from sys import stdout
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import peakutils
# %matplotlib inline 
from math import sqrt
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler, normalize, MinMaxScaler 
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
from sklearn.linear_model import ElasticNet,ElasticNetCV

import warnings
warnings.filterwarnings('ignore')

# %%
def optimise_pls_cv(X, y, n_comp, plot_components=True):
    '''Run PLS including a variable number of components, up to n_comp,
       and calculate MSE '''
    mse = []
    component = np.arange(1, n_comp)
    for i in component:
        pls = PLSRegression(n_components=i)
        # Cross-validation
        y_cv = cross_val_predict(pls, X, y, cv=10)
        mse.append(mean_squared_error(y, y_cv))
        comp = 100*(i+1)/40
        # Trick to update status on the same line
        stdout.write("\r%d%% completed" % comp)
        stdout.flush()
    stdout.write("\n")
    # Calculate and print the position of minimum in MSE
    msemin = np.argmin(mse)
    print("Suggested number of components: ", msemin+1)
    stdout.write("\n")
    if plot_components is True:
        with plt.style.context(('ggplot')):
            plt.plot(component, np.array(mse), '-v', color = 'blue', mfc='blue')
            plt.plot(component[msemin], np.array(mse)[msemin], 'P', ms=10, mfc='red')
            plt.xlabel('Number of PLS components')
            plt.ylabel('MSE')
            plt.title('PLS')
            plt.xlim(left=-1)
        plt.show()
    # Define PLS object with optimal number of components
    pls_opt = PLSRegression(n_components=msemin+1)
    # Fir to the entire dataset
    pls_opt.fit(X, y)
    y_c = pls_opt.predict(X)
    # Cross-validation
    y_cv = cross_val_predict(pls_opt, X, y, cv=10)
    # Calculate scores for calibration and cross-validation
    score_c = r2_score(y, y_c)
    score_cv = r2_score(y, y_cv)
    # Calculate mean squared error for calibration and cross validation
    mse_c = mean_squared_error(y, y_c)
    mse_cv = mean_squared_error(y, y_cv)
    print('R2 calib: %5.3f'  % score_c)
    print('R2 CV: %5.3f'  % score_cv)
    print('MSE calib: %5.3f' % mse_c)
    print('MSE CV: %5.3f' % mse_cv)
    
    return
    # Plot regression and figures of merit
    rangey = max(y) - min(y)
    rangex = max(y_c) - min(y_c)
"""   
    # Fit a line to the CV vs response
    z = np.polyfit(y, y_c, 1)
    with plt.style.context(('ggplot')):
        fig, ax = plt.subplots(figsize=(9, 5))
        ax.scatter(y_c, y, c='red', edgecolors='k')
        #Plot the best fit line
        ax.plot(np.polyval(z,y), y, c='blue', linewidth=1)
        #Plot the ideal 1:1 line
        ax.plot(y, y, color='green', linewidth=1)
        plt.title('$R^{2}$ (CV): '+str(score_cv))
        plt.xlabel('Predicted $^{\circ}$Brix')
        plt.ylabel('Measured $^{\circ}$Brix')
        plt.show()
    return
"""
# Out:
# "   \n    # Fit a line to the CV vs response\n    z = np.polyfit(y, y_c, 1)\n    with plt.style.context(('ggplot')):\n        fig, ax = plt.subplots(figsize=(9, 5))\n        ax.scatter(y_c, y, c='red', edgecolors='k')\n        #Plot the best fit line\n        ax.plot(np.polyval(z,y), y, c='blue', linewidth=1)\n        #Plot the ideal 1:1 line\n        ax.plot(y, y, color='green', linewidth=1)\n        plt.title('$R^{2}$ (CV): '+str(score_cv))\n        plt.xlabel('Predicted $^{\\circ}$Brix')\n        plt.ylabel('Measured $^{\\circ}$Brix')\n        plt.show()\n    return\n"

# %%
def pls_variable_selection(X, y, max_comp):
    
    # Define MSE array to be populated
    mse = np.zeros((max_comp,X.shape[1]))
    # Loop over the number of PLS components
    for i in range(max_comp):
        
        # Regression with specified number of components, using full spectrum
        pls1 = PLSRegression(n_components=i+1)
        pls1.fit(X, y)
        
        # Indices of sort spectra according to ascending absolute value of PLS coefficients
        sorted_ind = np.argsort(np.abs(pls1.coef_[:,0]))
        # Sort spectra accordingly 
        Xc = X[:,sorted_ind]
        # Discard one wavelength at a time of the sorted spectra,
        # regress, and calculate the MSE cross-validation
        for j in range(Xc.shape[1]-(i+1)):
            pls2 = PLSRegression(n_components=i+1)
            pls2.fit(Xc[:, j:], y)
            
            y_cv = cross_val_predict(pls2, Xc[:, j:], y, cv=5)
            mse[i,j] = mean_squared_error(y, y_cv)
    
        comp = 100*(i+1)/(max_comp)
        stdout.write("\r%d%% completed" % comp)
        stdout.flush()
    stdout.write("\n")
    # # Calculate and print the position of minimum in MSE
    mseminx,mseminy = np.where(mse==np.min(mse[np.nonzero(mse)]))
    print("Optimised number of PLS components: ", mseminx[0]+1)
    print("Wavelengths to be discarded ",mseminy[0])
    print('Optimised MSEP ', mse[mseminx,mseminy][0])
    stdout.write("\n")
    # plt.imshow(mse, interpolation=None)
    # plt.show()
    # Calculate PLS with optimal components and export values
    pls = PLSRegression(n_components=mseminx[0]+1)
    pls.fit(X, y)
        
    sorted_ind = np.argsort(np.abs(pls.coef_[:,0]))
    Xc = X[:,sorted_ind]
    return(Xc[:,mseminy[0]:],mseminx[0]+1,mseminy[0], sorted_ind)

# %%
def msc(input_data, reference=None):
    ''' Perform Multiplicative scatter correction'''
    # mean centre correction
    for i in range(input_data.shape[0]):
        input_data[i,:] -= input_data[i,:].mean()
    # Get the reference spectrum. If not given, estimate it from the mean    
    if reference is None:    
        # Calculate mean
        ref = np.mean(input_data, axis=0)
    else:
        ref = reference
    # Define a new array and populate it with the corrected data    
    data_msc = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
        # Run regression
        fit = np.polyfit(ref, input_data[i,:], 1, full=True)
        # Apply correction
        data_msc[i,:] = (input_data[i,:] - fit[0][1]) / fit[0][0] 
    return (data_msc, ref)

# %%
def snv(input_data):
  
    # Define a new array and populate it with the corrected data  
    data_snv = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
        # Apply correction
        data_snv[i,:] = (input_data[i,:] - np.mean(input_data[i,:])) / np.std(input_data[i,:])
    return data_snv

# %%
x_df = pd.read_csv('../avg_base_wl_25-02.csv', sep = ',')
values = x_df.values
#wl=x_df.columns.values
#print(wl.shape)

#print(values)
#print(type(values))
print(values.shape)
print(values[1].shape)
print(len(values))
x_df
# Out:
# (24, 1446)
# (1446,)
# 24
#     252.071400  252.201700  252.331900  252.462200  252.592400  252.722600  \
# 0    -7.864691  -32.876223  -81.441809   34.100714   -8.329733   -6.084499
# 1  -122.419869 -121.975190 -183.580510  -67.385822 -101.341118 -128.096389
# 2   -45.938542  -72.597810 -135.657078  -23.249675  -63.075597  -82.768172
# 3   -74.248689  -88.550836 -140.577119  -24.499950  -75.181390 -101.449020
# 4   113.773646   44.218164   13.704347  151.315527  114.676703  158.579536
# 5   117.523648   28.773685   -0.176279  167.373754  123.123781  157.073801
# 6   -46.131274  -59.723018 -111.939761    0.843499  -32.623234  -61.964955
# 7   -34.186038  -55.433807  -97.281576    7.020658  -47.677101  -45.024852
# 8    81.436124   17.374412  -15.946560  126.436168  100.189261  133.164567
# 9   242.174780  126.912135  124.316155  319.220170  283.457508  373.094829
# 10   53.230254   -3.626973  -47.291892  103.581648   52.609031   79.674872
# 11  -21.540100  -29.348794 -115.824154   28.700487  -42.774868  -56.583548
# 12  139.549549   59.006930   22.239309  181.021687  129.979059  189.236425
# 13  223.107190  113.292627   89.783618  266.024608  230.043369  295.145456
# 14  -11.939907  -59.197878  -88.055848   33.919516   -7.438448  -34.096405
# 15  -68.529632  -73.066960 -136.718573  -22.941610  -70.450351 -106.673363
# 16  -78.189487  -92.605431 -142.240124  -28.562312  -65.259489  -68.550398
# 17  143.780849   58.743087   27.589938  173.013708  145.360547  201.207374
# 18  136.377916   41.772137   15.984538  177.772694  142.772965  235.530802
# 19  233.596703  118.400946   74.621854  243.342761  188.146997  258.367891
# 20    1.697015  -77.178520  -86.508601   52.161320   20.513063   43.501176
# 21   74.629782    7.706264  -33.717255  110.992556   56.069029   83.978829
# 22  154.126083   83.776126   37.943409  191.317585  145.967616  182.721086
# 23  181.647922   84.686353   64.796209  233.334627  192.087315  267.197119
#
#     252.852900  252.983100  253.113300  253.243600  ...  428.718100  \
# 0    39.106688   81.595182   28.367469  -33.549423  ...  131.632928
# 1   -70.851622  -19.806804  -76.861917 -136.066946  ...   29.233677
# 2   -43.860727   14.513414  -45.112407  -88.838180  ...   49.048043
# 3   -59.647659   -6.122125  -58.286200  -98.795044  ...   29.181529
# 4   294.774023  290.760158  130.579601   11.149013  ...   30.602823
# 5   315.248808  282.623796  105.123761   -5.851304  ...   41.124975
# 6   -21.556660    9.601659  -43.864994  -99.831611  ...   66.274575
# 7     3.477412   31.929696  -16.517996  -75.215658  ...   79.536750
# 8   238.250968  250.374384  130.719991   26.658148  ...   97.588563
# 9   579.232128  543.736064  286.139963  152.310485  ...   67.471440
# 10  186.971475  202.460372   80.833865   -8.292670  ...  169.471210
# 11   15.274449   -1.867537  -34.676171 -103.484779  ...   73.987718
# 12  338.568779  336.176117  135.183434   15.740725  ...   30.678561
# 13  459.969752  450.738475  244.618287  118.081407  ...   38.225138
# 14   35.345648   94.121047   10.429794  -39.294774  ...  114.967305
# 15  -55.267780    4.737836  -70.599363 -128.593650  ...   38.568809
# 16  -10.778781   34.711622  -42.360431  -80.713679  ...   59.809465
# 17  350.784953  355.785585  178.978492   81.325206  ...   64.897700
# 18  413.621959  396.137337  202.743597   73.955882  ...   38.903280
# 19  410.797108  401.226310  207.280494   83.917990  ...   54.360380
# 20  148.989299  154.022885   24.147390  -49.682642  ...   14.702875
# 21  186.121952  184.665058   59.708142  -13.115469  ...   22.609127
# 22  295.474540  300.986593  142.360689   25.355441  ...   42.976647
# 23  434.735453  402.916585  223.454778  101.064299  ...   92.540945
#
#     428.828600   428.939000   429.049500  429.159900  429.270300  429.380600  \
# 0   476.037019  1355.860070  1037.412886  289.114382   45.829415  -58.928506
# 1   -61.440166   -92.663913  -100.237583  -59.411193  -46.334756 -129.158287
# 2   -37.678755   -49.138825   -56.865513   -6.225495  -13.052112  -82.745375
# 3   -47.446362   -38.177626   -59.701933  -11.295156  -35.509030 -105.136672
# 4   -51.837138  -114.277028   -83.466863  -16.073320  -37.513078  -93.661145
# 5   -28.011700    -8.773303   -20.259847  -13.946342  -29.982800 -112.469232
# 6   -27.007751   -51.790034   -48.197283    8.395497   13.238299  -57.418883
# 7   -14.535058   -18.406821    -4.628546   20.449761    1.178094  -55.443555
# 8     8.412306     0.680512   -12.421637   27.142895   21.374104  -32.246530
# 9   -23.401227   -49.440521   -47.779784   -3.185688   -0.991572  -39.530775
# 10  382.265374  1012.828788   851.084526  284.186434   73.903741  -31.840479
# 11  -23.624401    64.096852    74.151472   24.206122  -15.405871  -59.684514
# 12  -54.125877   -95.005239   -91.909539  -26.163791  -35.943006 -104.547195
# 13  -40.263361   -72.474038   -65.379124   -0.367514    4.810785  -51.233122
# 14  135.208883   413.250480   310.392098  127.567068   48.842055  -37.016277
# 15  -57.378059  -102.524852   -94.585870  -31.618270  -21.822062 -107.254400
# 16   67.859127   212.877596   147.708616   52.914679   -9.566722  -94.798098
# 17  -44.752215   -67.132847   -74.090360  -20.740149   -9.351451  -71.616581
# 18  -29.629005   -67.130904   -79.905465  -58.922399  -68.212020 -104.077373
# 19  -46.246362   -70.811391   -66.376384   -5.649681    7.702046  -46.237878
# 20  -50.962565   -14.946098   -57.656830  -29.458413  -66.396315 -140.879641
# 21  -37.894165   -12.864064   -22.733913   -1.737054  -26.006831  -90.243253
# 22  -45.798612   -70.780722   -57.383484    0.772404   -0.002719  -60.984722
# 23   25.210805    -5.369328    -1.735167   42.434715   42.854604   -9.582645
#
#     429.491000  429.601300  429.711600
# 0  -100.591822 -116.011889  -77.283306
# 1  -148.631798 -188.155299 -161.378796
# 2  -108.538624 -121.998532 -110.125106
# 3  -132.660848 -151.702258 -129.226424
# 4  -119.142531 -138.832243 -109.605286
# 5  -134.580649 -150.592057 -119.403464
# 6   -87.451055  -95.233222  -76.265387
# 7   -86.315192 -112.586823  -92.858452
# 8   -35.719011  -66.747045  -31.034337
# 9   -73.369968  -94.842491  -64.815013
# 10  -61.584692  -79.405825  -47.650034
# 11  -76.963146  -99.575106  -84.853731
# 12 -135.751369 -145.930535 -122.259698
# 13  -86.527019  -98.459800  -76.281468
# 14  -60.741269  -92.066256  -60.257908
# 15 -113.315293 -146.290464 -131.094204
# 16 -127.029459 -137.635813 -126.367163
# 17  -83.727854 -101.377583  -91.258080
# 18 -118.760890 -150.505005 -144.158207
# 19  -74.136125 -114.992699  -77.849272
# 20 -150.408402 -160.346245 -158.965903
# 21 -108.746328 -129.116063 -103.852462
# 22  -78.794301 -100.672840  -81.482412
# 23  -21.912747  -51.421419  -22.215805
#
# [24 rows x 1446 columns]

# %%
#This is just for visualizing the various plots of the samples

df = pd.read_csv('../ref_new/1.csv')
data=df.values
wl= data[0]
print(wl)

for i in range(len(values)):
    plt.plot(wl, data[i,:])
    #plt.show() #comment this one to have unique plot instead of multiple ones
#range(len(dfs))
#"""
# Out:
# [252.0714 252.2017 252.3319 ... 429.491  429.6013 429.7116]

# %%
df_y = pd.read_csv('../concentration_1.csv', sep = ',')
print(type(df_y))
concentration=df_y.values
print(concentration.shape)
#print(concentration)

y_values=df_y.values
y_all=pd.DataFrame(y_values[:,1:-2])
#print(y_all)
df_y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (24, 9)
#     Reference Number      Si     Fe     Mg      Zn      Cu     Mn       Al  \
# 0                  1   0.185  0.228  2.940  0.0304  0.0620  0.280  96.0000
# 1                  2   0.360  0.600  1.100  0.0700  0.2000  0.830  96.5787
# 2                  3   9.140  1.010  0.200  0.4200  3.6000  0.410  84.7770
# 3                  4   8.565  0.000  0.293  0.8870  2.6360  0.330  86.5650
# 4                  5   9.500  0.000  0.391  0.0000  0.0580  0.016  90.0210
# 5                  6   7.220  0.140  0.360  0.0840  0.1200  0.053  91.8090
# 6                  7   7.460  0.530  0.036  0.1400  0.1500  0.100  91.4140
# 7                  8  12.900  0.120  0.520  0.1550  0.5200  0.286  84.7905
# 8                  9   8.750  0.460  1.710  0.0290  2.0000  0.056  85.3100
# 9                 10   0.260  0.420  1.260  0.0200  0.0040  1.160  96.8346
# 10                11   0.070  0.100  0.410  0.1800  0.0600  1.450  97.6000
# 11                12   0.160  0.310  0.880  0.1000  0.1100  1.140  97.1500
# 12                13   6.120  0.000  0.320  0.0000  0.0054  0.016  93.5352
# 13                14  12.530  0.310  0.025  0.0500  0.0560  0.033  86.8180
# 14                15   0.530  0.230  0.770  0.0310  0.0060  0.024  98.3881
# 15                16   0.160  0.200  4.540  0.0520  0.0500  0.380  94.5340
# 16                17   3.000  0.795  0.570  0.1540  4.2900  0.037  90.4640
# 17                18   9.460  1.190  0.390  0.1600  3.1000  0.260  84.8070
# 18                19   0.530  0.180  3.570  5.0600  1.9000  0.130  88.2100
# 19                24   9.190  0.000  0.339  0.0000  0.0057  0.008  90.4538
# 20                25   6.160  0.000  0.363  0.0000  0.0060  0.206  93.2574
# 21                26   0.180  0.205  2.480  5.4400  1.6000  0.079  89.8430
# 22                28   0.180  0.500  1.110  0.0520  0.1500  1.260  96.7210
# 23                29   0.180  0.350  2.030  6.0800  1.3500  0.450  89.3900
#
#       Total
# 0   99.7254
# 1   99.7387
# 2   99.5570
# 3   99.2760
# 4   99.9860
# 5   99.7860
# 6   99.8300
# 7   99.2915
# 8   98.3150
# 9   99.9586
# 10  99.8700
# 11  99.8500
# 12  99.9966
# 13  99.8220
# 14  99.9791
# 15  99.9160
# 16  99.3100
# 17  99.3670
# 18  99.5800
# 19  99.9965
# 20  99.9924
# 21  99.8270
# 22  99.9730
# 23  99.8300

# %%
y_val = concentration[:,3] #1-Si, 2-Fe, 3-Mg, 5-Cu, 6-Mn (4-Zn but too much sparse)
print(y_val)
print(y_val.shape)
y_df= pd.DataFrame(y_val)
#y_df
# Out:
# [2.94  1.1   0.2   0.293 0.391 0.36  0.036 0.52  1.71  1.26  0.41  0.88
#  0.32  0.025 0.77  4.54  0.57  0.39  3.57  0.339 0.363 2.48  1.11  2.03 ]
# (24,)

# %% [markdown]
# # Genetic Algorithm with PLS

# %%
import random

import numpy as np
from deap import base
from deap import creator
from deap import tools
from sklearn import datasets
from sklearn import model_selection
from sklearn.cross_decomposition import PLSRegression

# %%
x_std= snv(values)
print(x_std.shape)

autoscaled_X_train, X_test, autoscaled_y_train, y_test = train_test_split(x_std, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print(y_test)
# Out:
# (24, 1446)
# (24, 1446) (24,)
# (5, 1446) (5, 1)
#         0
# 2   0.200
# 5   0.360
# 8   1.710
# 7   0.520
# 19  0.339

# %%
X_train=values
y_train= y_val

#autoscaled_X_train= X_train
#autoscaled_y_train=y_train

autoscaled_X_train= (X_train - X_train.mean(axis=0)) / X_train.std(axis=0, ddof=1)
autoscaled_y_train = (y_train - y_train.mean()) / y_train.std(ddof=1)
print(autoscaled_X_train.shape)
print(autoscaled_y_train.shape)

print(np.linalg.matrix_rank(autoscaled_X_train))
# Out:
# (24, 1446)
# (24,)
# 23

# %%
# settings
number_of_population = 100
number_of_generation = 200
max_number_of_components = 10
fold_number = 5
probability_of_crossover = 0.5
probability_of_mutation = 0.2
threshold_of_variable_selection = 0.5


# GAPLS
creator.create('FitnessMax', base.Fitness, weights=(1.0,))  # for minimization, set weights as (-1.0,)
creator.create('Individual', list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
min_boundary = np.zeros(X_train.shape[1])
max_boundary = np.ones(X_train.shape[1]) * 1.0
#print(min_boundary.shape)
#print(max_boundary.shape)


###this one is for selecting at random the "individual"
def create_ind_uniform(min_boundary, max_boundary):
    index = []
    for min, max in zip(min_boundary, max_boundary):
        index.append(random.uniform(min, max))
    return index


toolbox.register('create_ind', create_ind_uniform, min_boundary, max_boundary)
toolbox.register('individual', tools.initIterate, creator.Individual, toolbox.create_ind)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)


def evalOneMax(individual):
    individual_array = np.array(individual)
    #individual array is an array of lenght "wl" with values between 0 and 1. 
    #print("individual_array", individual_array.shape)
    
    selected_X_variable_numbers = np.where(individual_array > threshold_of_variable_selection)[0]
    #If an element of ind_arr is bigger than thresh it is kept. this one will be used for the selection of selected_autoscaled_X_train
    #print("selected_X_variable_numbers: ", selected_X_variable_numbers.shape)
    
    selected_autoscaled_X_train = autoscaled_X_train[:, selected_X_variable_numbers]
    #print("selected_autoscaled_X_train: ", selected_autoscaled_X_train.shape)

    
    if len(selected_X_variable_numbers):
        # cross-validation
        #print("np.linalg.matrix_rank(selected_autoscaled_X_train)", np.linalg.matrix_rank(selected_autoscaled_X_train))
        
        #print("AAAA ", min(np.linalg.matrix_rank(selected_autoscaled_X_train) + 1, max_number_of_components + 1))
        
        pls_components = np.arange(1, min(min(selected_autoscaled_X_train.shape[0],selected_autoscaled_X_train.shape[1]) + 1,
                                          max_number_of_components + 1), 1)
        #pls_components = np.arange(1, min(np.linalg.matrix_rank(selected_autoscaled_X_train) + 1,
        #                                  max_number_of_components + 1), 1)
        #print("pls components: ", pls_components)
        
        r2_cv_all = []
        
        for pls_component in pls_components:
            
            model_in_cv = PLSRegression(n_components=pls_component)
            
            #print("selected_autoscaled_X_train",selected_autoscaled_X_train)
            
            estimated_y_train_in_cv = np.ndarray.flatten(
                model_selection.cross_val_predict(model_in_cv, selected_autoscaled_X_train, autoscaled_y_train, cv=fold_number))
            
            
            
            estimated_y_train_in_cv = estimated_y_train_in_cv * y_train.std(ddof=1) + y_train.mean()
            r2_cv_all.append(1 - sum((y_train - estimated_y_train_in_cv) ** 2) / sum((y_train - y_train.mean()) ** 2))
        #print(len(r2_cv_all))
        #print("r2_cv_all: ",r2_cv_all)
        """
        try:
            value = np.max(r2_cv_all)
        except ValueError:  #raised if `y` is empty.
            value = -999
            pass
        """
        value = np.max(r2_cv_all)
        
    else:
        value = -999

    return value,


toolbox.register('evaluate', evalOneMax)
toolbox.register('mate', tools.cxTwoPoint)
toolbox.register('mutate', tools.mutFlipBit, indpb=0.05)
toolbox.register('select', tools.selTournament, tournsize=3)

# random.seed(100)
random.seed()
pop = toolbox.population(n=number_of_population)

print('Start of evolution')

fitnesses = list(map(toolbox.evaluate, pop))
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

print('  Evaluated %i individuals' % len(pop))

for generation in range(number_of_generation):
    print('-- Generation {0} --'.format(generation + 1))

    offspring = toolbox.select(pop, len(pop))
    offspring = list(map(toolbox.clone, offspring))

    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < probability_of_crossover:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < probability_of_mutation:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    print('  Evaluated %i individuals' % len(invalid_ind))

    pop[:] = offspring
    fits = [ind.fitness.values[0] for ind in pop]

    length = len(pop)
    mean = sum(fits) / length
    sum2 = sum(x * x for x in fits)
    std = abs(sum2 / length - mean ** 2) ** 0.5

    print('  Min %s' % min(fits))
    print('  Max %s' % max(fits))
    print('  Avg %s' % mean)
    print('  Std %s' % std)

print('-- End of (successful) evolution --')

best_individual = tools.selBest(pop, 1)[0]
best_individual_array = np.array(best_individual)
selected_X_variable_numbers = np.where(best_individual_array > threshold_of_variable_selection)[0]
print('Selected variables : %s, %s' % (selected_X_variable_numbers, best_individual.fitness.values))
# Out:
# Start of evolution
#   Evaluated 100 individuals
# -- Generation 1 --
#   Evaluated 61 individuals
#   Min -0.11874629498094169
#   Max 0.007648706780606251
#   Avg -0.03787068924643299
#   Std 0.025896948498573297
# -- Generation 2 --
#   Evaluated 50 individuals
#   Min -0.0775030849539109
#   Max 0.04402822067663825
#   Avg -0.018185296374024582
#   Std 0.01886282627079197
# -- Generation 3 --
#   Evaluated 65 individuals
#   Min -0.052043196248876544
#   Max 0.04402822067663825
#   Avg -0.0027112007658757096
#   Std 0.018514133215629
# -- Generation 4 --
#   Evaluated 57 individuals
#   Min -0.026237834461820597
#   Max 0.05656846490277012
#   Avg 0.008861938054389536
#   Std 0.016054890565967646
# -- Generation 5 --
#   Evaluated 62 individuals
#   Min -0.01925786355196668
#   Max 0.07254091516790828
#   Avg 0.019168783074456356
#   Std 0.015210764060301519
# -- Generation 6 --
#   Evaluated 54 individuals
#   Min -0.0052059432304867315
#   Max 0.07546955758131502
#   Avg 0.032234413272799294
#   Std 0.016257578890363448
# -- Generation 7 --
#   Evaluated 54 individuals
#   Min 0.012768589316912937
#   Max 0.07762089856695531
#   Avg 0.04737293424341707
#   Std 0.014995842340491122
# -- Generation 8 --
#   Evaluated 64 individuals
#   Min 0.01908488961151933
#   Max 0.08272666104215765
#   Avg 0.05998900030497514
#   Std 0.01261085977846114
# -- Generation 9 --
#   Evaluated 69 individuals
#   Min 0.04178984572651834
#   Max 0.09039768681938909
#   Avg 0.06822799908970636
#   Std 0.009772825320458835
# -- Generation 10 --
#   Evaluated 56 individuals
#   Min 0.04435186678785341
#   Max 0.1029830187295332
#   Avg 0.07681801526971117
#   Std 0.008360619923622787
# -- Generation 11 --
#   Evaluated 58 individuals
#   Min 0.06690267554135909
#   Max 0.10895272226122932
#   Avg 0.08217696293459217
#   Std 0.007884407707007185
# -- Generation 12 --
#   Evaluated 57 individuals
#   Min 0.0729603234201679
#   Max 0.11224500069161691
#   Avg 0.0891081280440659
#   Std 0.008001874690290539
# -- Generation 13 --
#   Evaluated 67 individuals
#   Min 0.05977108887010818
#   Max 0.12003547722724128
#   Avg 0.09337054004542798
#   Std 0.010018901783074229
# -- Generation 14 --
#   Evaluated 47 individuals
#   Min 0.07271458692574395
#   Max 0.12244562640694323
#   Avg 0.10035307230025557
#   Std 0.010199724021203156
# -- Generation 15 --
#   Evaluated 62 individuals
#   Min 0.06906534616218796
#   Max 0.12978257165629203
#   Avg 0.10750754598749415
#   Std 0.008528907366635962
# -- Generation 16 --
#   Evaluated 66 individuals
#   Min 0.08539717115096201
#   Max 0.1304715684824942
#   Avg 0.11175189508137211
#   Std 0.008003184128593358
# -- Generation 17 --
#   Evaluated 53 individuals
#   Min 0.08740369318245433
#   Max 0.13611897192759326
#   Avg 0.11620851743484882
#   Std 0.009372936640621271
# -- Generation 18 --
#   Evaluated 67 individuals
#   Min 0.09680162498739142
#   Max 0.1443405410015106
#   Avg 0.12192207255549507
#   Std 0.00909943981265367
# -- Generation 19 --
#   Evaluated 69 individuals
#   Min 0.09380178829989905
#   Max 0.14894254660592332
#   Avg 0.1275163413900689
#   Std 0.009122689150004326
# -- Generation 20 --
#   Evaluated 50 individuals
#   Min 0.10245151307916445
#   Max 0.14894254660592332
#   Avg 0.13251459523089257
#   Std 0.008252305352713069
# -- Generation 21 --
#   Evaluated 74 individuals
#   Min 0.11375941208954132
#   Max 0.15658542701660616
#   Avg 0.13673394030169952
#   Std 0.0077095728093417954
# -- Generation 22 --
#   Evaluated 70 individuals
#   Min 0.10692974986442327
#   Max 0.15190982503657235
#   Avg 0.1403934747241331
#   Std 0.007395972744999606
# -- Generation 23 --
#   Evaluated 66 individuals
#   Min 0.09650218447586012
#   Max 0.1640880321294016
#   Avg 0.14427043045505938
#   Std 0.008349196380730976
# -- Generation 24 --
#   Evaluated 52 individuals
#   Min 0.1238549014371686
#   Max 0.1648094369901616
#   Avg 0.14822228790994843
#   Std 0.0072462136763794425
# -- Generation 25 --
#   Evaluated 46 individuals
#   Min 0.12993906052566873
#   Max 0.17763544725022296
#   Avg 0.151817007456627
#   Std 0.007801955992995507
# -- Generation 26 --
#   Evaluated 52 individuals
#   Min 0.12282424405139492
#   Max 0.18061708141512522
#   Avg 0.15607942663977994
#   Std 0.008332051593854842
# -- Generation 27 --
#   Evaluated 58 individuals
#   Min 0.10588836176832972
#   Max 0.18165908854848345
#   Avg 0.15850266854867376
#   Std 0.009772892417520692
# -- Generation 28 --
#   Evaluated 71 individuals
#   Min 0.1441916102607136
#   Max 0.18238863367261982
#   Avg 0.16208356148331016
#   Std 0.007924893581186187
# -- Generation 29 --
#   Evaluated 38 individuals
#   Min 0.1346580905353768
#   Max 0.18291789210440412
#   Avg 0.16657112629357884
#   Std 0.008287452281916635
# -- Generation 30 --
#   Evaluated 60 individuals
#   Min 0.14371468742509652
#   Max 0.18759785200306
#   Avg 0.17050898315532428
#   Std 0.009151582867292967
# -- Generation 31 --
#   Evaluated 61 individuals
#   Min 0.13790837489956764
#   Max 0.19246189925016843
#   Avg 0.1746387304405982
#   Std 0.00982556271760977
# -- Generation 32 --
#   Evaluated 59 individuals
#   Min 0.15135266004785797
#   Max 0.19246189925016843
#   Avg 0.17895454649766962
#   Std 0.00777051723915312
# -- Generation 33 --
#   Evaluated 50 individuals
#   Min 0.14328202978568116
#   Max 0.19366486919774795
#   Avg 0.18205595069156275
#   Std 0.008587108012928061
# -- Generation 34 --
#   Evaluated 56 individuals
#   Min 0.15549979506201583
#   Max 0.20680462455017612
#   Avg 0.18602326274481476
#   Std 0.007405603170653463
# -- Generation 35 --
#   Evaluated 66 individuals
#   Min 0.1442840910699743
#   Max 0.204331930605414
#   Avg 0.18813944357882753
#   Std 0.008871426339460147
# -- Generation 36 --
#   Evaluated 60 individuals
#   Min 0.15630486321645243
#   Max 0.204331930605414
#   Avg 0.19059719630384842
#   Std 0.008466698879343298
# -- Generation 37 --
#   Evaluated 65 individuals
#   Min 0.17404369423297306
#   Max 0.20495718167915966
#   Avg 0.19423104587965553
#   Std 0.006682902681682958
# -- Generation 38 --
#   Evaluated 67 individuals
#   Min 0.16286873937229207
#   Max 0.20875949286044648
#   Avg 0.19673978614091475
#   Std 0.008246876485467477
# -- Generation 39 --
#   Evaluated 60 individuals
#   Min 0.1553490935916566
#   Max 0.21816881514308617
#   Avg 0.19977319627521986
#   Std 0.008533564093632507
# -- Generation 40 --
#   Evaluated 78 individuals
#   Min 0.17261290020283004
#   Max 0.21816881514308617
#   Avg 0.20162189107919784
#   Std 0.008752549324659142
# -- Generation 41 --
#   Evaluated 59 individuals
#   Min 0.1641273254635086
#   Max 0.22551651493244396
#   Avg 0.20500710810229478
#   Std 0.008213826413242106
# -- Generation 42 --
#   Evaluated 67 individuals
#   Min 0.16344889598008516
#   Max 0.22551651493244396
#   Avg 0.20761771543846153
#   Std 0.010187870688050585
# -- Generation 43 --
#   Evaluated 63 individuals
#   Min 0.1849641537004949
#   Max 0.22551651493244396
#   Avg 0.21203824916639863
#   Std 0.008221677211562115
# -- Generation 44 --
#   Evaluated 60 individuals
#   Min 0.19323256777714093
#   Max 0.22551651493244396
#   Avg 0.21581062385199565
#   Std 0.007206551045591238
# -- Generation 45 --
#   Evaluated 74 individuals
#   Min 0.18060895082297967
#   Max 0.22703641738466684
#   Avg 0.21687969830582682
#   Std 0.008730108328052927
# -- Generation 46 --
#   Evaluated 65 individuals
#   Min 0.18870810781140346
#   Max 0.22896934417657366
#   Avg 0.21969219150157734
#   Std 0.006784633212971312
# -- Generation 47 --
#   Evaluated 61 individuals
#   Min 0.16129975305504796
#   Max 0.2294091753920675
#   Avg 0.22039423524029644
#   Std 0.009377670259843884
# -- Generation 48 --
#   Evaluated 59 individuals
#   Min 0.18412635083181017
#   Max 0.235220491035657
#   Avg 0.2215846499394744
#   Std 0.00915711164783954
# -- Generation 49 --
#   Evaluated 66 individuals
#   Min 0.1813993167839839
#   Max 0.235220491035657
#   Avg 0.2234714999137447
#   Std 0.009663196538336544
# -- Generation 50 --
#   Evaluated 61 individuals
#   Min 0.1899406550714079
#   Max 0.23584781118365095
#   Avg 0.22517803014323942
#   Std 0.009701888835105737
# -- Generation 51 --
#   Evaluated 57 individuals
#   Min 0.2046111658588181
#   Max 0.23584781118365095
#   Avg 0.22782692972973917
#   Std 0.007539506272933709
# -- Generation 52 --
#   Evaluated 67 individuals
#   Min 0.19547772392197882
#   Max 0.23659909972317705
#   Avg 0.22900436906619193
#   Std 0.009143339698423882
# -- Generation 53 --
#   Evaluated 60 individuals
#   Min 0.1941369828384415
#   Max 0.23663975238144075
#   Avg 0.23009584943961753
#   Std 0.008750671014108162
# -- Generation 54 --
#   Evaluated 58 individuals
#   Min 0.16898033984430316
#   Max 0.23707967244012895
#   Avg 0.23106236297932398
#   Std 0.010360489731629558
# -- Generation 55 --
#   Evaluated 50 individuals
#   Min 0.1935876928233582
#   Max 0.2409867437873756
#   Avg 0.23227974228283446
#   Std 0.008085554868345573
# -- Generation 56 --
#   Evaluated 60 individuals
#   Min 0.18741887332257945
#   Max 0.2409867437873756
#   Avg 0.2310385783199886
#   Std 0.011169508043141893
# -- Generation 57 --
#   Evaluated 74 individuals
#   Min 0.1965566316056111
#   Max 0.2409867437873756
#   Avg 0.2341200790580919
#   Std 0.007928709851336677
# -- Generation 58 --
#   Evaluated 61 individuals
#   Min 0.20794804248410215
#   Max 0.242353380016452
#   Avg 0.23448817181095694
#   Std 0.0077226056117747745
# -- Generation 59 --
#   Evaluated 59 individuals
#   Min 0.20437473453284483
#   Max 0.242353380016452
#   Avg 0.2344572360507644
#   Std 0.008587350252328669
# -- Generation 60 --
#   Evaluated 55 individuals
#   Min 0.21445624502345828
#   Max 0.242353380016452
#   Avg 0.23583978896738003
#   Std 0.008084025506711539
# -- Generation 61 --
#   Evaluated 61 individuals
#   Min 0.20341652380536546
#   Max 0.2464914144675301
#   Avg 0.23653734852857142
#   Std 0.008243085128799699
# -- Generation 62 --
#   Evaluated 59 individuals
#   Min 0.20802036373415445
#   Max 0.2464914144675301
#   Avg 0.2380143133033016
#   Std 0.008048639484531082
# -- Generation 63 --
#   Evaluated 69 individuals
#   Min 0.20916877279788038
#   Max 0.2471248721795003
#   Avg 0.237561394036765
#   Std 0.009174650613644036
# -- Generation 64 --
#   Evaluated 51 individuals
#   Min 0.20631114071166534
#   Max 0.2471248721795003
#   Avg 0.23770433282622655
#   Std 0.00986843575580873
# -- Generation 65 --
#   Evaluated 56 individuals
#   Min 0.2131404665360248
#   Max 0.2471248721795003
#   Avg 0.24065827798316689
#   Std 0.0066357278806658
# -- Generation 66 --
#   Evaluated 59 individuals
#   Min 0.19840167580785073
#   Max 0.2471248721795003
#   Avg 0.24079800615300143
#   Std 0.00808674739206944
# -- Generation 67 --
#   Evaluated 60 individuals
#   Min 0.211650602796972
#   Max 0.24865778680879536
#   Avg 0.24061413563985934
#   Std 0.00938485700059331
# -- Generation 68 --
#   Evaluated 56 individuals
#   Min 0.20724456243869638
#   Max 0.24865778680879536
#   Avg 0.24103453312575376
#   Std 0.010715655538004616
# -- Generation 69 --
#   Evaluated 68 individuals
#   Min 0.20901767390091408
#   Max 0.24890068305637525
#   Avg 0.24197064256503836
#   Std 0.009349751815162647
# -- Generation 70 --
#   Evaluated 57 individuals
#   Min 0.21144000701735222
#   Max 0.25158117855327744
#   Avg 0.2421325310927978
#   Std 0.009781148345908625
# -- Generation 71 --
#   Evaluated 73 individuals
#   Min 0.19840608739741927
#   Max 0.25158117855327744
#   Avg 0.24190653213861196
#   Std 0.010837271598997365
# -- Generation 72 --
#   Evaluated 75 individuals
#   Min 0.1940362745976526
#   Max 0.24960288747396997
#   Avg 0.24231515410077262
#   Std 0.010914390513367971
# -- Generation 73 --
#   Evaluated 53 individuals
#   Min 0.209844752674468
#   Max 0.25099181543225446
#   Avg 0.24511057353383456
#   Std 0.008351135971370795
# -- Generation 74 --
#   Evaluated 61 individuals
#   Min 0.21316013013360002
#   Max 0.2517059195298299
#   Avg 0.24381330155018535
#   Std 0.01015170107876078
# -- Generation 75 --
#   Evaluated 63 individuals
#   Min 0.2112595083077009
#   Max 0.25510978451880995
#   Avg 0.24535918485837932
#   Std 0.009474403833834945
# -- Generation 76 --
#   Evaluated 65 individuals
#   Min 0.20689411999239837
#   Max 0.25531552851064154
#   Avg 0.24560895831814325
#   Std 0.010502078906050816
# -- Generation 77 --
#   Evaluated 60 individuals
#   Min 0.2133631371652983
#   Max 0.25531552851064154
#   Avg 0.24622873077178797
#   Std 0.010159772373088308
# -- Generation 78 --
#   Evaluated 56 individuals
#   Min 0.19114268060773798
#   Max 0.25624547435782374
#   Avg 0.24624270939994994
#   Std 0.011481787968472944
# -- Generation 79 --
#   Evaluated 61 individuals
#   Min 0.22277206533061644
#   Max 0.25624547435782374
#   Avg 0.24928900365656495
#   Std 0.007594482396895348
# -- Generation 80 --
#   Evaluated 61 individuals
#   Min 0.21458444942046861
#   Max 0.26210750151966333
#   Avg 0.24883473058598038
#   Std 0.009935424721575813
# -- Generation 81 --
#   Evaluated 62 individuals
#   Min 0.2084455648104636
#   Max 0.26210750151966333
#   Avg 0.24959359942043785
#   Std 0.011286850667537459
# -- Generation 82 --
#   Evaluated 61 individuals
#   Min 0.22562705731534904
#   Max 0.26210750151966333
#   Avg 0.2533076775661104
#   Std 0.007969941876192186
# -- Generation 83 --
#   Evaluated 66 individuals
#   Min 0.2044565647750155
#   Max 0.26210750151966333
#   Avg 0.2536023910260369
#   Std 0.011000963376404214
# -- Generation 84 --
#   Evaluated 65 individuals
#   Min 0.22333210666861958
#   Max 0.262758186156256
#   Avg 0.2570466961917552
#   Std 0.008559701055994153
# -- Generation 85 --
#   Evaluated 65 individuals
#   Min 0.2153937817900181
#   Max 0.2634531664382733
#   Avg 0.25604431709814374
#   Std 0.011124216958339246
# -- Generation 86 --
#   Evaluated 57 individuals
#   Min 0.21866385030790514
#   Max 0.2643498002067224
#   Avg 0.2561180597158443
#   Std 0.01135835878808327
# -- Generation 87 --
#   Evaluated 53 individuals
#   Min 0.2165868482999349
#   Max 0.2643498002067224
#   Avg 0.2566929283880099
#   Std 0.011269060555670358
# -- Generation 88 --
#   Evaluated 52 individuals
#   Min 0.22746436754603705
#   Max 0.26537787742072716
#   Avg 0.25887051134671324
#   Std 0.008613985770061712
# -- Generation 89 --
#   Evaluated 59 individuals
#   Min 0.2272557696978792
#   Max 0.26537787742072716
#   Avg 0.26066146473987833
#   Std 0.006928039061788432
# -- Generation 90 --
#   Evaluated 67 individuals
#   Min 0.22569998716346018
#   Max 0.2654013708377957
#   Avg 0.25989131982180247
#   Std 0.008979633815657194
# -- Generation 91 --
#   Evaluated 72 individuals
#   Min 0.2173360187759691
#   Max 0.2662240935244272
#   Avg 0.2582427147081306
#   Std 0.011324518583894286
# -- Generation 92 --
#   Evaluated 55 individuals
#   Min 0.21042321010435117
#   Max 0.2662491200416982
#   Avg 0.2609033759501701
#   Std 0.009374450233007538
# -- Generation 93 --
#   Evaluated 65 individuals
#   Min 0.22784442114330505
#   Max 0.2662491200416982
#   Avg 0.26087295228398555
#   Std 0.009439661233608784
# -- Generation 94 --
#   Evaluated 62 individuals
#   Min 0.2183809764432123
#   Max 0.2662491200416982
#   Avg 0.26044319605302796
#   Std 0.011182174660156132
# -- Generation 95 --
#   Evaluated 57 individuals
#   Min 0.2256387256250303
#   Max 0.2663081692580146
#   Avg 0.26076845602225956
#   Std 0.010887905834211155
# -- Generation 96 --
#   Evaluated 63 individuals
#   Min 0.22393136790808033
#   Max 0.2663081692580146
#   Avg 0.26217991809905944
#   Std 0.00959732000073234
# -- Generation 97 --
#   Evaluated 43 individuals
#   Min 0.2188801236699749
#   Max 0.2664658935238359
#   Avg 0.2627817472345017
#   Std 0.008295506528284556
# -- Generation 98 --
#   Evaluated 49 individuals
#   Min 0.22729009112457144
#   Max 0.2664658935238359
#   Avg 0.2611686407329471
#   Std 0.01013346419914084
# -- Generation 99 --
#   Evaluated 59 individuals
#   Min 0.21813755388405942
#   Max 0.2664658935238359
#   Avg 0.2604934810193659
#   Std 0.011085509485597273
# -- Generation 100 --
#   Evaluated 66 individuals
#   Min 0.23184062850192322
#   Max 0.2720986385952031
#   Avg 0.26172685230334286
#   Std 0.008996494254917723
# -- Generation 101 --
#   Evaluated 64 individuals
#   Min 0.2281050388635425
#   Max 0.2720986385952031
#   Avg 0.2632556738661973
#   Std 0.008106964854416386
# -- Generation 102 --
#   Evaluated 63 individuals
#   Min 0.21876680060967446
#   Max 0.2720986385952031
#   Avg 0.26151541188812355
#   Std 0.011052575732195572
# -- Generation 103 --
#   Evaluated 53 individuals
#   Min 0.22605986542936674
#   Max 0.2721239047997739
#   Avg 0.26418754628857655
#   Std 0.007885059407583427
# -- Generation 104 --
#   Evaluated 62 individuals
#   Min 0.2064797940305454
#   Max 0.2770298753484054
#   Avg 0.26294809428907856
#   Std 0.01247694678929998
# -- Generation 105 --
#   Evaluated 52 individuals
#   Min 0.21798098779196362
#   Max 0.2775620110125848
#   Avg 0.26450648754505335
#   Std 0.012885834554611345
# -- Generation 106 --
#   Evaluated 62 individuals
#   Min 0.2217119703742788
#   Max 0.2770298753484054
#   Avg 0.2679217394478084
#   Std 0.010182661766330148
# -- Generation 107 --
#   Evaluated 57 individuals
#   Min 0.23760197255867443
#   Max 0.27721359316225214
#   Avg 0.27055172460253835
#   Std 0.007911063197283977
# -- Generation 108 --
#   Evaluated 53 individuals
#   Min 0.23223174731659457
#   Max 0.27835956620645275
#   Avg 0.2691420751706329
#   Std 0.010434491462793474
# -- Generation 109 --
#   Evaluated 53 individuals
#   Min 0.22535204423768973
#   Max 0.27835956620645275
#   Avg 0.26948026516526336
#   Std 0.012310215704610515
# -- Generation 110 --
#   Evaluated 68 individuals
#   Min 0.23981083536080539
#   Max 0.27835956620645275
#   Avg 0.26990903294806745
#   Std 0.011011290781048427
# -- Generation 111 --
#   Evaluated 56 individuals
#   Min 0.23887927233533912
#   Max 0.2790263785670384
#   Avg 0.2732551784531279
#   Std 0.00915268937799226
# -- Generation 112 --
#   Evaluated 62 individuals
#   Min 0.2238150338099828
#   Max 0.2790263785670384
#   Avg 0.27246873850552933
#   Std 0.01117005009139078
# -- Generation 113 --
#   Evaluated 51 individuals
#   Min 0.23106198126672828
#   Max 0.2790806742572407
#   Avg 0.2741627253795388
#   Std 0.009660183055159583
# -- Generation 114 --
#   Evaluated 57 individuals
#   Min 0.2317478696860117
#   Max 0.2794612020105687
#   Avg 0.27288253673876706
#   Std 0.011866046161394757
# -- Generation 115 --
#   Evaluated 58 individuals
#   Min 0.23627528694546107
#   Max 0.27950828961352114
#   Avg 0.2747358401069305
#   Std 0.009732491911990352
# -- Generation 116 --
#   Evaluated 61 individuals
#   Min 0.22921335192230818
#   Max 0.27950828961352114
#   Avg 0.2729661019196072
#   Std 0.01173526458201368
# -- Generation 117 --
#   Evaluated 66 individuals
#   Min 0.22008083341519502
#   Max 0.27950828961352114
#   Avg 0.2740931143455188
#   Std 0.01155292098948263
# -- Generation 118 --
#   Evaluated 63 individuals
#   Min 0.22840950743549737
#   Max 0.27950828961352114
#   Avg 0.2716806385508163
#   Std 0.013745768340057753
# -- Generation 119 --
#   Evaluated 73 individuals
#   Min 0.233348469927391
#   Max 0.2796517094996247
#   Avg 0.2735333984670298
#   Std 0.01142130606914351
# -- Generation 120 --
#   Evaluated 71 individuals
#   Min 0.22780953064251575
#   Max 0.27950828961352114
#   Avg 0.27667967750670514
#   Std 0.009128926269837396
# -- Generation 121 --
#   Evaluated 68 individuals
#   Min 0.21798500312483826
#   Max 0.2796077255436191
#   Avg 0.2737553435331161
#   Std 0.012529457756935439
# -- Generation 122 --
#   Evaluated 58 individuals
#   Min 0.24012543193625646
#   Max 0.2796077255436191
#   Avg 0.27553199543898504
#   Std 0.009292233084616368
# -- Generation 123 --
#   Evaluated 70 individuals
#   Min 0.23821541529724444
#   Max 0.2811326355266638
#   Avg 0.275984479086133
#   Std 0.008952267117978864
# -- Generation 124 --
#   Evaluated 74 individuals
#   Min 0.22532141258997673
#   Max 0.28130700912019657
#   Avg 0.2722213597642694
#   Std 0.01417066183923022
# -- Generation 125 --
#   Evaluated 57 individuals
#   Min 0.23282744211949336
#   Max 0.28299137468270086
#   Avg 0.27411138791584405
#   Std 0.012024341419233217
# -- Generation 126 --
#   Evaluated 63 individuals
#   Min 0.24107216530980335
#   Max 0.28299137468270086
#   Avg 0.27600171477966706
#   Std 0.009692849028910603
# -- Generation 127 --
#   Evaluated 55 individuals
#   Min 0.24419128251065314
#   Max 0.28320918544938534
#   Avg 0.2763145250165086
#   Std 0.00957584182379274
# -- Generation 128 --
#   Evaluated 50 individuals
#   Min 0.237858242257738
#   Max 0.2843439154413827
#   Avg 0.27680472792334265
#   Std 0.010896983472726274
# -- Generation 129 --
#   Evaluated 66 individuals
#   Min 0.2226989840835022
#   Max 0.2861043369530296
#   Avg 0.2772067932738849
#   Std 0.010996403671629306
# -- Generation 130 --
#   Evaluated 63 individuals
#   Min 0.24501079207403997
#   Max 0.2867285548624908
#   Avg 0.2777211391038738
#   Std 0.010497149443900112
# -- Generation 131 --
#   Evaluated 65 individuals
#   Min 0.2465578445550427
#   Max 0.2861043369530296
#   Avg 0.2802971988780938
#   Std 0.008798806750035396
# -- Generation 132 --
#   Evaluated 60 individuals
#   Min 0.2353824999031593
#   Max 0.2875585435423458
#   Avg 0.28028663233904266
#   Std 0.010608102288402548
# -- Generation 133 --
#   Evaluated 64 individuals
#   Min 0.23683991018352557
#   Max 0.2875585435423458
#   Avg 0.27998199553901953
#   Std 0.011612791961353465
# -- Generation 134 --
#   Evaluated 63 individuals
#   Min 0.23692837790007282
#   Max 0.28780697800628885
#   Avg 0.2789747883199683
#   Std 0.012367967876175822
# -- Generation 135 --
#   Evaluated 48 individuals
#   Min 0.25167488005992145
#   Max 0.28780697800628885
#   Avg 0.2820279328221014
#   Std 0.009493094205099245
# -- Generation 136 --
#   Evaluated 57 individuals
#   Min 0.23958729098910547
#   Max 0.2879362142177003
#   Avg 0.28046955257979816
#   Std 0.012624595337094952
# -- Generation 137 --
#   Evaluated 67 individuals
#   Min 0.25444346654469363
#   Max 0.28820131203961263
#   Avg 0.28245326603374843
#   Std 0.009837107224373202
# -- Generation 138 --
#   Evaluated 61 individuals
#   Min 0.23993817770507397
#   Max 0.28831934493296996
#   Avg 0.2800576329755544
#   Std 0.012697584307781095
# -- Generation 139 --
#   Evaluated 56 individuals
#   Min 0.23194612057438224
#   Max 0.28831934493296996
#   Avg 0.2814553954514428
#   Std 0.01290590398110857
# -- Generation 140 --
#   Evaluated 68 individuals
#   Min 0.23774098008510025
#   Max 0.28831934493296996
#   Avg 0.28130062609613193
#   Std 0.012602774466685559
# -- Generation 141 --
#   Evaluated 54 individuals
#   Min 0.20956577139783483
#   Max 0.28831934493296996
#   Avg 0.28286067267026943
#   Std 0.012141365888171782
# -- Generation 142 --
#   Evaluated 49 individuals
#   Min 0.24857612770109228
#   Max 0.28831934493296996
#   Avg 0.2850067158824914
#   Std 0.009615108385800973
# -- Generation 143 --
#   Evaluated 61 individuals
#   Min 0.2536827942216904
#   Max 0.28831934493296996
#   Avg 0.28465644391116374
#   Std 0.008451609567735212
# -- Generation 144 --
#   Evaluated 60 individuals
#   Min 0.2472990343399608
#   Max 0.28831934493296996
#   Avg 0.2826060778160536
#   Std 0.011455339947652129
# -- Generation 145 --
#   Evaluated 56 individuals
#   Min 0.24443700945456748
#   Max 0.28831934493296996
#   Avg 0.2830628910537007
#   Std 0.010586995731206866
# -- Generation 146 --
#   Evaluated 58 individuals
#   Min 0.23623187236324839
#   Max 0.28831934493296996
#   Avg 0.2840402977909612
#   Std 0.010010272125378613
# -- Generation 147 --
#   Evaluated 58 individuals
#   Min 0.25329213449968946
#   Max 0.28831934493296996
#   Avg 0.28342951054705207
#   Std 0.010471772403544733
# -- Generation 148 --
#   Evaluated 60 individuals
#   Min 0.2410528693433458
#   Max 0.28831934493296996
#   Avg 0.2841893232745711
#   Std 0.009990270749592514
# -- Generation 149 --
#   Evaluated 64 individuals
#   Min 0.24812492038125844
#   Max 0.28831934493296996
#   Avg 0.2843798804049197
#   Std 0.009678645948697322
# -- Generation 150 --
#   Evaluated 64 individuals
#   Min 0.24650256533734038
#   Max 0.2883281929901985
#   Avg 0.2829705700564116
#   Std 0.010623430281256065
# -- Generation 151 --
#   Evaluated 67 individuals
#   Min 0.23163542585731067
#   Max 0.2883281929901985
#   Avg 0.2821327379325954
#   Std 0.012812574586350546
# -- Generation 152 --
#   Evaluated 61 individuals
#   Min 0.24725828535630268
#   Max 0.28831934493296996
#   Avg 0.28318430601962374
#   Std 0.011563735392576149
# -- Generation 153 --
#   Evaluated 60 individuals
#   Min 0.2459928544949046
#   Max 0.28831934493296996
#   Avg 0.283976897355975
#   Std 0.009949753102678548
# -- Generation 154 --
#   Evaluated 49 individuals
#   Min 0.25000032520242654
#   Max 0.28831934493296996
#   Avg 0.2843599053002317
#   Std 0.009581583485289548
# -- Generation 155 --
#   Evaluated 54 individuals
#   Min 0.22723251998041505
#   Max 0.28831934493296996
#   Avg 0.28430042845998593
#   Std 0.01167678830050484
# -- Generation 156 --
#   Evaluated 45 individuals
#   Min 0.24985905029952915
#   Max 0.28831934493296996
#   Avg 0.28351593586810353
#   Std 0.010074396117796824
# -- Generation 157 --
#   Evaluated 60 individuals
#   Min 0.23710437213455837
#   Max 0.28831934493296996
#   Avg 0.28310284297635174
#   Std 0.01166431112694496
# -- Generation 158 --
#   Evaluated 69 individuals
#   Min 0.24376667231429416
#   Max 0.28831934493296996
#   Avg 0.2814691618061477
#   Std 0.012222570193487943
# -- Generation 159 --
#   Evaluated 48 individuals
#   Min 0.24270747991095254
#   Max 0.28831934493296996
#   Avg 0.28284914278501544
#   Std 0.011844820554373334
# -- Generation 160 --
#   Evaluated 66 individuals
#   Min 0.2457394133023617
#   Max 0.28831934493296996
#   Avg 0.2834911376934743
#   Std 0.0106433157274637
# -- Generation 161 --
#   Evaluated 62 individuals
#   Min 0.24372976361780185
#   Max 0.28831934493296996
#   Avg 0.2828067948409594
#   Std 0.01064734621043343
# -- Generation 162 --
#   Evaluated 69 individuals
#   Min 0.239633075467779
#   Max 0.28831934493296996
#   Avg 0.28336161899059453
#   Std 0.010837568734043398
# -- Generation 163 --
#   Evaluated 62 individuals
#   Min 0.2327819054921112
#   Max 0.28831934493296996
#   Avg 0.28105679671243133
#   Std 0.013374604100241922
# -- Generation 164 --
#   Evaluated 62 individuals
#   Min 0.2343792863632954
#   Max 0.28831934493296996
#   Avg 0.28231369102496534
#   Std 0.012155451319461467
# -- Generation 165 --
#   Evaluated 71 individuals
#   Min 0.24676389792968056
#   Max 0.28831934493296996
#   Avg 0.28301666747717075
#   Std 0.011045797369319472
# -- Generation 166 --
#   Evaluated 56 individuals
#   Min 0.24278173873579922
#   Max 0.28831934493296996
#   Avg 0.2841914212025234
#   Std 0.010427814522164467
# -- Generation 167 --
#   Evaluated 56 individuals
#   Min 0.2489412344184897
#   Max 0.28831934493296996
#   Avg 0.28416847687538255
#   Std 0.00995608814927621
# -- Generation 168 --
#   Evaluated 59 individuals
#   Min 0.24745534715075246
#   Max 0.28831934493296996
#   Avg 0.28237368741586616
#   Std 0.011288485223993412
# -- Generation 169 --
#   Evaluated 65 individuals
#   Min 0.24761695577064324
#   Max 0.28831934493296996
#   Avg 0.2818768024902853
#   Std 0.011194824551720474
# -- Generation 170 --
#   Evaluated 66 individuals
#   Min 0.232485723687068
#   Max 0.28831934493296996
#   Avg 0.28106280361784886
#   Std 0.013347538577851044
# -- Generation 171 --
#   Evaluated 68 individuals
#   Min 0.240415349871841
#   Max 0.28831934493296996
#   Avg 0.2816371544225718
#   Std 0.012566397578680619
# -- Generation 172 --
#   Evaluated 65 individuals
#   Min 0.24532346753136813
#   Max 0.28831934493296996
#   Avg 0.28291484815527956
#   Std 0.01096869976030962
# -- Generation 173 --
#   Evaluated 50 individuals
#   Min 0.25027150692685873
#   Max 0.28831934493296996
#   Avg 0.2839915270760226
#   Std 0.010014893960567432
# -- Generation 174 --
#   Evaluated 54 individuals
#   Min 0.23849229780845382
#   Max 0.28831934493296996
#   Avg 0.281423497619539
#   Std 0.0130524386475242
# -- Generation 175 --
#   Evaluated 66 individuals
#   Min 0.24515354369767772
#   Max 0.28831934493296996
#   Avg 0.28245068323678685
#   Std 0.011545312447084925
# -- Generation 176 --
#   Evaluated 59 individuals
#   Min 0.24883411725691962
#   Max 0.28831934493296996
#   Avg 0.2837080947145655
#   Std 0.010173349283797522
# -- Generation 177 --
#   Evaluated 60 individuals
#   Min 0.23665835378058786
#   Max 0.28831934493296996
#   Avg 0.28171113431158895
#   Std 0.012940147989886422
# -- Generation 178 --
#   Evaluated 73 individuals
#   Min 0.24607895610701191
#   Max 0.28831934493296996
#   Avg 0.28415531849787273
#   Std 0.009413096099828875
# -- Generation 179 --
#   Evaluated 58 individuals
#   Min 0.24885144201023812
#   Max 0.28831934493296996
#   Avg 0.28289114159103185
#   Std 0.010894208358292313
# -- Generation 180 --
#   Evaluated 61 individuals
#   Min 0.2511598070641021
#   Max 0.28831934493296996
#   Avg 0.2838284994338476
#   Std 0.009960811937717692
# -- Generation 181 --
#   Evaluated 54 individuals
#   Min 0.24316089850375222
#   Max 0.28831934493296996
#   Avg 0.2832702884491767
#   Std 0.011351083936460685
# -- Generation 182 --
#   Evaluated 54 individuals
#   Min 0.2486039508345158
#   Max 0.28831934493296996
#   Avg 0.2820793192317832
#   Std 0.012292560921342193
# -- Generation 183 --
#   Evaluated 69 individuals
#   Min 0.2336963000634078
#   Max 0.28831934493296996
#   Avg 0.2814883996621612
#   Std 0.013496461912007082
# -- Generation 184 --
#   Evaluated 50 individuals
#   Min 0.23285869329822084
#   Max 0.2884313738381101
#   Avg 0.283462158458012
#   Std 0.011905406094771668
# -- Generation 185 --
#   Evaluated 61 individuals
#   Min 0.22994002722145246
#   Max 0.2884313738381101
#   Avg 0.280666224327484
#   Std 0.013637852048483482
# -- Generation 186 --
#   Evaluated 62 individuals
#   Min 0.24843338871731124
#   Max 0.2884313738381101
#   Avg 0.28390161108568895
#   Std 0.009750380212536467
# -- Generation 187 --
#   Evaluated 53 individuals
#   Min 0.24979007224588823
#   Max 0.2884313738381101
#   Avg 0.28354137257343714
#   Std 0.01020526053419869
# -- Generation 188 --
#   Evaluated 61 individuals
#   Min 0.23597106767279763
#   Max 0.2884992492532116
#   Avg 0.28275605944302795
#   Std 0.011410726103536882
# -- Generation 189 --
#   Evaluated 61 individuals
#   Min 0.24561199393336297
#   Max 0.2884992492532116
#   Avg 0.2840270801806967
#   Std 0.009670754664944532
# -- Generation 190 --
#   Evaluated 57 individuals
#   Min 0.2427979474043449
#   Max 0.2884992492532116
#   Avg 0.2825333078290472
#   Std 0.011815099806438235
# -- Generation 191 --
#   Evaluated 53 individuals
#   Min 0.23716664289229528
#   Max 0.2884992492532116
#   Avg 0.28468345404005163
#   Std 0.010273705254581123
# -- Generation 192 --
#   Evaluated 69 individuals
#   Min 0.2390434620374544
#   Max 0.2884992492532116
#   Avg 0.282049402911772
#   Std 0.012955292111665921
# -- Generation 193 --
#   Evaluated 59 individuals
#   Min 0.24866614228710493
#   Max 0.2884992492532116
#   Avg 0.28301961337284165
#   Std 0.011003972635913148
# -- Generation 194 --
#   Evaluated 57 individuals
#   Min 0.23635816818526756
#   Max 0.2884992492532116
#   Avg 0.2828954488514199
#   Std 0.012462729705965936
# -- Generation 195 --
#   Evaluated 43 individuals
#   Min 0.23422679649286338
#   Max 0.2884992492532116
#   Avg 0.283814470606693
#   Std 0.011155566993819421
# -- Generation 196 --
#   Evaluated 60 individuals
#   Min 0.24159632813599918
#   Max 0.2884992492532116
#   Avg 0.28475623171921904
#   Std 0.009375586215455993
# -- Generation 197 --
#   Evaluated 54 individuals
#   Min 0.25526165080996743
#   Max 0.2884992492532116
#   Avg 0.28578960256684494
#   Std 0.007651337069477516
# -- Generation 198 --
#   Evaluated 70 individuals
#   Min 0.24241825061034117
#   Max 0.2884992492532116
#   Avg 0.2816481922895853
#   Std 0.012435687448285668
# -- Generation 199 --
#   Evaluated 64 individuals
#   Min 0.2441055182508709
#   Max 0.2884992492532116
#   Avg 0.2796811812237971
#   Std 0.01225364597001163
# -- Generation 200 --
#   Evaluated 64 individuals
#   Min 0.24292191971306853
#   Max 0.2885394613937964
#   Avg 0.28184005697859577
#   Std 0.011591399871691587
# -- End of (successful) evolution --
# Selected variables : [   2    8   11   14   15   24   28   29   31   34   38   44   47   48
#    50   69   73   74   85   96   97   99  102  109  110  112  115  117
#   120  121  122  123  125  132  134  137  141  152  155  157  158  159
#   162  164  170  171  172  174  178  182  183  185  187  191  195  200
#   202  204  207  208  215  219  222  228  229  232  238  239  241  244
#   248  249  250  252  261  265  267  268  269  270  271  274  275  282
#   283  285  288  289  290  291  293  294  295  298  302  303  304  305
#   306  307  308  315  316  317  318  321  322  323  326  328  339  340
#   341  342  344  353  357  372  376  378  379  380  381  383  384  385
#   386  388  389  390  394  396  397  398  399  404  405  406  408  409
#   411  419  423  424  425  427  429  431  432  433  438  440  442  443
#   444  446  447  448  449  452  454  455  458  459  460  462  463  466
#   467  469  471  472  473  475  476  477  479  484  488  490  494  495
#   496  499  503  505  506  507  509  510  513  514  516  517  518  522
#   533  536  546  551  553  560  564  574  582  583  585  592  595  596
#   597  601  608  609  616  623  625  634  636  644  652  654  668  671
#   680  686  697  698  699  700  702  703  709  710  712  728  732  741
#   747  748  749  750  751  752  753  757  759  766  768  772  773  774
#   775  780  782  784  785  787  791  793  794  805  809  810  812  818
#   821  822  824  825  828  830  836  837  847  850  855  866  870  872
#   876  880  881  884  886  890  891  892  895  897  898  899  900  901
#   902  910  911  914  919  921  926  929  931  933  935  937  940  941
#   943  946  949  950  955  956  958  959  961  962  965  968  970  973
#   974  978  980  985  986  989  990  993  994 1002 1009 1013 1015 1018
#  1025 1026 1031 1036 1037 1039 1044 1045 1049 1052 1053 1055 1056 1057
#  1058 1061 1064 1073 1079 1086 1088 1089 1090 1097 1098 1104 1107 1113
#  1114 1119 1120 1122 1127 1128 1129 1130 1131 1133 1138 1140 1143 1145
#  1146 1148 1156 1158 1159 1160 1162 1163 1164 1166 1167 1170 1175 1176
#  1177 1186 1187 1189 1190 1196 1198 1203 1205 1207 1221 1223 1224 1228
#  1229 1234 1235 1237 1238 1241 1243 1244 1246 1247 1248 1251 1269 1272
#  1278 1280 1284 1286 1288 1289 1290 1293 1294 1297 1302 1308 1315 1323
#  1324 1327 1329 1333 1334 1343 1349 1352 1353 1357 1358 1360 1362 1365
#  1377 1379 1380 1381 1382 1384 1385 1386 1395 1396 1398 1400 1402 1404
#  1414 1415 1418 1419 1422 1423 1429 1432 1442], (0.2885394613937964,)

# %%
print(selected_X_variable_numbers.shape)

#print(wl[selected_X_variable_numbers].T)
# Out:
# (471,)

# %%
x_selecta = pd.DataFrame(x_df.values[:,selected_X_variable_numbers])

# %%
#X_train, X_test, y_train, y_test = train_test_split(x_selecta, y_df, test_size=0.2, random_state = 3) #seed for Mg = 3, 16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Si = 7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 16) #seed for Cu =16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Fe =7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 3) #seed for Mn = 3

X_train, X_test, y_train, y_test = train_test_split(x_selecta, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print(y_test)
# Out:
# (19, 471) (19, 1)
# (5, 471) (5, 1)
#        0
# 0   2.94
# 1   1.10
# 21  2.48
# 16  0.57
# 15  4.54

# %%
optimise_pls_cv(X_train, y_train, 15, plot_components=True)
# Out:
# 37% completed
# Suggested number of components:  3
# R2 calib: 0.790
# R2 CV: 0.381
# MSE calib: 0.149
# MSE CV: 0.441

# %%
# Define PLS object
pls = PLSRegression(n_components=22)
# Fit
pls.fit(X_train, y_train)

y_pred = pls.predict(X_test)
y_pred1 = pls.predict(X_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")


c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  -1.01615044426894
# RMSE:  1.9968952742409332

# %%
start_time = time.time()

opt_Xc, ncomp, wav, sorted_ind = pls_variable_selection(x_selecta.values, y_val, 15)
#opt_Xc, ncomp, wav, sorted_ind = pls_variable_selection(x_df.values, y_val, 15)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 100% completed
# Optimised number of PLS components:  11
# Wavelengths to be discarded  442
# Optimised MSEP  0.4343921385780714
#
# --- 86.8049852848053 seconds ---

# %%
#print(opt_Xc.shape,"\n")
#print("sorted indexes: ", sorted_ind)
print("sorted wavelengths: ", wl[sorted_ind[:10]].T)

plt.plot(opt_Xc.T)
plt.show()
# Out:
# sorted wavelengths:  [295.1776 292.0938 281.7845 301.5874 302.6111 302.3552 260.9201 271.6935
#  300.4352 285.2688]

# %%
#X_train, X_test, y_train, y_test = train_test_split(x_selecta, y_df, test_size=0.2, random_state = 16) #seed for Mg = 3, 16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Si = 7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 16) #seed for Cu =16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Fe =7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 3) #seed for Mn = 3

X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print(y_test)
# Out:
# (19, 29) (19, 1)
# (5, 29) (5, 1)
#        0
# 21  2.48
# 18  3.57
# 12  0.32
# 15  4.54
# 2   0.20

# %%
optimise_pls_cv(X_train,y_train, 30, plot_components=True)
# Out:
# 75% completed
# Suggested number of components:  9
# R2 calib: 0.994
# R2 CV: 0.111
# MSE calib: 0.003
# MSE CV: 0.467

# %%
# Define PLS object
pls = PLSRegression(n_components=11)
# Fit
pls.fit(X_train, y_train)

y_pred = pls.predict(X_test)
y_pred1 = pls.predict(X_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")


c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  0.281248629904822
# RMSE:  1.466600865987044

# %%
# -*- coding: utf-8 -*- 
# %reset -f
"""
@author: Hiromasa Kaneko
"""
# Demonstration of (binary) Genetic Algorithm-based Partial Least Squares (GAPLS)


import random

import numpy as np
from deap import base
from deap import creator
from deap import tools
from sklearn import datasets
from sklearn import model_selection
from sklearn.cross_decomposition import PLSRegression

# settings
number_of_population = 100
number_of_generation = 150
max_number_of_components = 10
fold_number = 5
probability_of_crossover = 0.5
probability_of_mutation = 0.2
threshold_of_variable_selection = 0.5

# generate sample dataset
X_train, y_train = datasets.make_regression(n_samples=100, n_features=300, n_informative=10, noise=10, random_state=0)

# autoscaling
autoscaled_X_train = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0, ddof=1)
#autoscaled_X_train = X_train
autoscaled_y_train = (y_train - y_train.mean()) / y_train.std(ddof=1)
#autoscaled_y_train = y_train
print(autoscaled_X_train.shape)
print(autoscaled_y_train.shape)


# GAPLS
creator.create('FitnessMax', base.Fitness, weights=(1.0,))  # for minimization, set weights as (-1.0,)
creator.create('Individual', list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
min_boundary = np.zeros(X_train.shape[1])
max_boundary = np.ones(X_train.shape[1]) * 1.0


def create_ind_uniform(min_boundary, max_boundary):
    index = []
    for min, max in zip(min_boundary, max_boundary):
        index.append(random.uniform(min, max))
    return index


toolbox.register('create_ind', create_ind_uniform, min_boundary, max_boundary)
toolbox.register('individual', tools.initIterate, creator.Individual, toolbox.create_ind)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)


def evalOneMax(individual):
    individual_array = np.array(individual)
    selected_X_variable_numbers = np.where(individual_array > threshold_of_variable_selection)[0]
    selected_autoscaled_X_train = autoscaled_X_train[:, selected_X_variable_numbers]
    
    #print("selected_autoscaled_X_train: ", selected_autoscaled_X_train.shape)
    
    if len(selected_X_variable_numbers):
        # cross-validation
        
        #print("np.linalg.matrix_rank(selected_autoscaled_X_train", np.linalg.matrix_rank(selected_autoscaled_X_train))
        
        ### THIS IS MY MODIFICATION OF THE ALGORITHM
        pls_components = np.arange(1, min(min(selected_autoscaled_X_train.shape[0],selected_autoscaled_X_train.shape[1]) + 1,
                                          max_number_of_components + 1), 1)
        
        #pls_components = np.arange(1, min(np.linalg.matrix_rank(selected_autoscaled_X_train) + 1,
         #                                 max_number_of_components + 1), 1)
        r2_cv_all = []
        for pls_component in pls_components:
            model_in_cv = PLSRegression(n_components=pls_component)
            estimated_y_train_in_cv = np.ndarray.flatten(
                model_selection.cross_val_predict(model_in_cv, selected_autoscaled_X_train, autoscaled_y_train,
                                                  cv=fold_number))
            estimated_y_train_in_cv = estimated_y_train_in_cv * y_train.std(ddof=1) + y_train.mean()
            r2_cv_all.append(1 - sum((y_train - estimated_y_train_in_cv) ** 2) / sum((y_train - y_train.mean()) ** 2))
        value = np.max(r2_cv_all)
    else:
        value = -999

    return value,


toolbox.register('evaluate', evalOneMax)
toolbox.register('mate', tools.cxTwoPoint)
toolbox.register('mutate', tools.mutFlipBit, indpb=0.05)
toolbox.register('select', tools.selTournament, tournsize=3)

# random.seed(100)
random.seed()
pop = toolbox.population(n=number_of_population)

print('Start of evolution')

fitnesses = list(map(toolbox.evaluate, pop))
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

print('  Evaluated %i individuals' % len(pop))

for generation in range(number_of_generation):
    print('-- Generation {0} --'.format(generation + 1))

    offspring = toolbox.select(pop, len(pop))
    offspring = list(map(toolbox.clone, offspring))

    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < probability_of_crossover:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < probability_of_mutation:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    print('  Evaluated %i individuals' % len(invalid_ind))

    pop[:] = offspring
    fits = [ind.fitness.values[0] for ind in pop]

    length = len(pop)
    mean = sum(fits) / length
    sum2 = sum(x * x for x in fits)
    std = abs(sum2 / length - mean ** 2) ** 0.5

    print('  Min %s' % min(fits))
    print('  Max %s' % max(fits))
    print('  Avg %s' % mean)
    print('  Std %s' % std)

print('-- End of (successful) evolution --')

best_individual = tools.selBest(pop, 1)[0]
best_individual_array = np.array(best_individual)
selected_X_variable_numbers = np.where(best_individual_array > threshold_of_variable_selection)[0]
print('Selected variables : %s, %s' % (selected_X_variable_numbers, best_individual.fitness.values))
# Out:
# (100, 300)
# (100,)
# Start of evolution
#   Evaluated 100 individuals
# -- Generation 1 --
#   Evaluated 53 individuals
#   Min -11067.233144441487
#   Max -7474.0937260201
#   Avg -9355.296608860162
#   Std 686.7273315690823
# -- Generation 2 --
#   Evaluated 65 individuals
#   Min -9949.338627869049
#   Max -6995.36057687397
#   Avg -8806.443169190885
#   Std 536.0016759635755
# -- Generation 3 --
#   Evaluated 58 individuals
#   Min -9494.860218530916
#   Max -6967.653506932216
#   Avg -8336.990633819893
#   Std 568.9917503605409
# -- Generation 4 --
#   Evaluated 59 individuals
#   Min -9366.694460621517
#   Max -6876.648209208637
#   Avg -7876.34822198962
#   Std 587.4312620638225
# -- Generation 5 --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c8c902a320e0> in <module>
#     126     invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     127     fitnesses = map(toolbox.evaluate, invalid_ind)
# --> 128     for ind, fit in zip(invalid_ind, fitnesses):
#     129         ind.fitness.values = fit
#     130
#
# <ipython-input-12-c8c902a320e0> in evalOneMax(individual)
#      80             estimated_y_train_in_cv = np.ndarray.flatten(
#      81                 model_selection.cross_val_predict(model_in_cv, selected_autoscaled_X_train, autoscaled_y_train,
# ---> 82                                                   cv=fold_number))
#      83             estimated_y_train_in_cv = estimated_y_train_in_cv * y_train.std(ddof=1) + y_train.mean()
#      84             r2_cv_all.append(1 - sum((y_train - estimated_y_train_in_cv) ** 2) / sum((y_train - y_train.mean()) ** 2))
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     753     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     754         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 755         for train, test in cv.split(X, y, groups))
#     756
#     757     # Concatenate the predictions
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     839         estimator.fit(X_train, **fit_params)
#     840     else:
# --> 841         estimator.fit(X_train, y_train, **fit_params)
#     842     func = getattr(estimator, method)
#     843     predictions = func(X_test)
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\cross_decomposition\_pls.py in fit(self, X, Y)
#     348             y_scores = np.dot(Yk, y_weights) / y_ss
#     349             # test for null variance
# --> 350             if np.dot(x_scores.T, x_scores) < np.finfo(np.double).eps:
#     351                 warnings.warn('X scores are null at iteration %s' % k)
#     352                 break
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*- 
# %reset -f
"""
@author: Hiromasa Kaneko
"""
# Demonstration of (binary) Genetic Algorithm-based Partial Least Squares (GAPLS)


import random

import numpy as np
from deap import base
from deap import creator
from deap import tools
from sklearn import datasets
from sklearn import model_selection
from sklearn.cross_decomposition import PLSRegression

# settings
number_of_population = 100
number_of_generation = 150
max_number_of_components = 10
fold_number = 5
probability_of_crossover = 0.5
probability_of_mutation = 0.2
threshold_of_variable_selection = 0.5

# generate sample dataset
X_train, y_train = datasets.make_regression(n_samples=100, n_features=300, n_informative=10, noise=10, random_state=0)

# autoscaling
autoscaled_X_train = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0, ddof=1)
#autoscaled_X_train = X_train
autoscaled_y_train = (y_train - y_train.mean()) / y_train.std(ddof=1)
#autoscaled_y_train = y_train
print(autoscaled_X_train.shape)
print(autoscaled_y_train.shape)


# GAPLS
creator.create('FitnessMax', base.Fitness, weights=(1.0,))  # for minimization, set weights as (-1.0,)
creator.create('Individual', list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
min_boundary = np.zeros(X_train.shape[1])
max_boundary = np.ones(X_train.shape[1]) * 1.0


def create_ind_uniform(min_boundary, max_boundary):
    index = []
    for min, max in zip(min_boundary, max_boundary):
        index.append(random.uniform(min, max))
    return index


toolbox.register('create_ind', create_ind_uniform, min_boundary, max_boundary)
toolbox.register('individual', tools.initIterate, creator.Individual, toolbox.create_ind)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)


def evalOneMax(individual):
    individual_array = np.array(individual)
    selected_X_variable_numbers = np.where(individual_array > threshold_of_variable_selection)[0]
    selected_autoscaled_X_train = autoscaled_X_train[:, selected_X_variable_numbers]
    
    #print("selected_autoscaled_X_train: ", selected_autoscaled_X_train.shape)
    
    if len(selected_X_variable_numbers):
        # cross-validation
        
        #print("np.linalg.matrix_rank(selected_autoscaled_X_train", np.linalg.matrix_rank(selected_autoscaled_X_train))
        
        ### THIS IS MY MODIFICATION OF THE ALGORITHM
        pls_components = np.arange(1, min(min(selected_autoscaled_X_train.shape[0],selected_autoscaled_X_train.shape[1]) + 1,
                                          max_number_of_components + 1), 1)
        
        #pls_components = np.arange(1, min(np.linalg.matrix_rank(selected_autoscaled_X_train) + 1,
         #                                 max_number_of_components + 1), 1)
        r2_cv_all = []
        for pls_component in pls_components:
            model_in_cv = PLSRegression(n_components=pls_component)
            estimated_y_train_in_cv = np.ndarray.flatten(
                model_selection.cross_val_predict(model_in_cv, selected_autoscaled_X_train, autoscaled_y_train,
                                                  cv=fold_number))
            estimated_y_train_in_cv = estimated_y_train_in_cv * y_train.std(ddof=1) + y_train.mean()
            r2_cv_all.append(1 - sum((y_train - estimated_y_train_in_cv) ** 2) / sum((y_train - y_train.mean()) ** 2))
        value = np.max(r2_cv_all)
    else:
        value = -999

    return value,


toolbox.register('evaluate', evalOneMax)
toolbox.register('mate', tools.cxTwoPoint)
toolbox.register('mutate', tools.mutFlipBit, indpb=0.05)
toolbox.register('select', tools.selTournament, tournsize=3)

# random.seed(100)
random.seed()
pop = toolbox.population(n=number_of_population)

print('Start of evolution')

fitnesses = list(map(toolbox.evaluate, pop))
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

print('  Evaluated %i individuals' % len(pop))

for generation in range(number_of_generation):
    print('-- Generation {0} --'.format(generation + 1))

    offspring = toolbox.select(pop, len(pop))
    offspring = list(map(toolbox.clone, offspring))

    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < probability_of_crossover:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < probability_of_mutation:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    print('  Evaluated %i individuals' % len(invalid_ind))

    pop[:] = offspring
    fits = [ind.fitness.values[0] for ind in pop]

    length = len(pop)
    mean = sum(fits) / length
    sum2 = sum(x * x for x in fits)
    std = abs(sum2 / length - mean ** 2) ** 0.5

    print('  Min %s' % min(fits))
    print('  Max %s' % max(fits))
    print('  Avg %s' % mean)
    print('  Std %s' % std)

print('-- End of (successful) evolution --')

best_individual = tools.selBest(pop, 1)[0]
best_individual_array = np.array(best_individual)
selected_X_variable_numbers = np.where(best_individual_array > threshold_of_variable_selection)[0]
print('Selected variables : %s, %s' % (selected_X_variable_numbers, best_individual.fitness.values))
# Out:
# (100, 300)
# (100,)
# Start of evolution
#   Evaluated 100 individuals
# -- Generation 1 --
#   Evaluated 64 individuals
#   Min -0.2624933541950494
#   Max 0.46170756718616024
#   Avg 0.14267219705004808
#   Std 0.14881491527603397
# -- Generation 2 --
#   Evaluated 58 individuals
#   Min -0.16039377957377243
#   Max 0.49361513086543063
#   Avg 0.2632540505603719
#   Std 0.12259475817814904
# -- Generation 3 --
#   Evaluated 59 individuals
#   Min 0.04498058469883337
#   Max 0.6113113283881253
#   Avg 0.35039711113622274
#   Std 0.08879021686133548
# -- Generation 4 --
#   Evaluated 64 individuals
#   Min 0.07704270283454695
#   Max 0.6566606322454047
#   Avg 0.4148732330680762
#   Std 0.09050431314455466
# -- Generation 5 --
#   Evaluated 63 individuals
#   Min 0.10013567022875891
#   Max 0.6647248014971939
#   Avg 0.4581790166493427
#   Std 0.09455475013174726
# -- Generation 6 --
#   Evaluated 55 individuals
#   Min 0.08025124606066136
#   Max 0.6647248014971939
#   Avg 0.5040987543646974
#   Std 0.08674545476744416
# -- Generation 7 --
#   Evaluated 56 individuals
#   Min 0.19159411234282597
#   Max 0.6761032266368215
#   Avg 0.5374886912867776
#   Std 0.09355951790802551
# -- Generation 8 --
#   Evaluated 64 individuals
#   Min 0.40537985290368683
#   Max 0.6933985964033121
#   Avg 0.5914069629079219
#   Std 0.06006115007853375
# -- Generation 9 --
#   Evaluated 60 individuals
#   Min 0.07827373318367403
#   Max 0.7113699945232937
#   Avg 0.6063624852918462
#   Std 0.08851858696502472
# -- Generation 10 --
#   Evaluated 54 individuals
#   Min 0.16557788027173437
#   Max 0.7499659530498649
#   Avg 0.6480992757320664
#   Std 0.06571942428448749
# -- Generation 11 --
#   Evaluated 50 individuals
#   Min 0.35336245745967854
#   Max 0.7503451568260862
#   Avg 0.671324175150248
#   Std 0.061194794289610666
# -- Generation 12 --
#   Evaluated 62 individuals
#   Min 0.2634989385803752
#   Max 0.7793900942388206
#   Avg 0.682591944625998
#   Std 0.08455987327714902
# -- Generation 13 --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-f8ed20cfa0bf> in <module>
#     122     invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     123     fitnesses = map(toolbox.evaluate, invalid_ind)
# --> 124     for ind, fit in zip(invalid_ind, fitnesses):
#     125         ind.fitness.values = fit
#     126
#
# <ipython-input-117-f8ed20cfa0bf> in evalOneMax(individual)
#      76             estimated_y_train_in_cv = np.ndarray.flatten(
#      77                 model_selection.cross_val_predict(model_in_cv, selected_autoscaled_X_train, autoscaled_y_train,
# ---> 78                                                   cv=fold_number))
#      79             estimated_y_train_in_cv = estimated_y_train_in_cv * y_train.std(ddof=1) + y_train.mean()
#      80             r2_cv_all.append(1 - sum((y_train - estimated_y_train_in_cv) ** 2) / sum((y_train - y_train.mean()) ** 2))
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     753     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     754         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 755         for train, test in cv.split(X, y, groups))
#     756
#     757     # Concatenate the predictions
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     839         estimator.fit(X_train, **fit_params)
#     840     else:
# --> 841         estimator.fit(X_train, y_train, **fit_params)
#     842     func = getattr(estimator, method)
#     843     predictions = func(X_test)
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\cross_decomposition\_pls.py in fit(self, X, Y)
#     346             else:
#     347                 y_ss = np.dot(y_weights.T, y_weights)
# --> 348             y_scores = np.dot(Yk, y_weights) / y_ss
#     349             # test for null variance
#     350             if np.dot(x_scores.T, x_scores) < np.finfo(np.double).eps:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
x_df.shape
# Out:
# (24, 1446)

# %%
x_selecta = pd.DataFrame(x_df.values[:,selected_X_variable_numbers])

# %%
selected_X_variable_numbers.shape
# Out:
# (87,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_selecta, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print(y_test)
# Out:
# (19, 87) (19, 1)
# (5, 87) (5, 1)
#         0
# 9   1.260
# 23  2.030
# 12  0.320
# 3   0.293
# 4   0.391

# %% [markdown]
# # Principal Components Analysis

# %%
n_components=20


x = x_df.values
print(x.shape)
print(x[1].shape)
print(len(x))


# This has to be used later for regression, PCA is done on X only
"""
y_df = pd.read_csv('labels_aligned+.csv', sep = ',')
concentration=y_df.values
#print(concentration)
multi_y = concentration[:,2:]
#print (multi_y)
print (multi_y.shape)
multi_y= np.array(multi_y, dtype=np.float)
y=np.around(multi_y, decimals=4)
#print(y)
"""

# PCA

X_std = StandardScaler().fit_transform(x)
#print(X_std)

pca = PCA(n_components= n_components)
PC=pca.fit(X_std)

principalComponents = pca.fit_transform(X_std)
print(principalComponents.shape)
#principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 'principal component 3'])
#print(principalDf)


#print(pca.explained_variance_ratio_)
print(np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100))
#print(pca.singular_values_)
# Out:
# (24, 1446)
# (1446,)
# 24
# (24, 20)
# [32.16 58.34 69.76 79.23 85.78 89.43 91.66 93.69 95.11 96.32 97.1  97.7
#  98.23 98.57 98.83 99.08 99.28 99.46 99.61 99.75]

# %%
regr = linear_model.LinearRegression()
# Fit
regr.fit(principalComponents, y_df)
# Calibration
y_c = regr.predict(principalComponents)
# Cross-validation
y_cv = cross_val_predict(regr, principalComponents, y_df, cv=10)
# Calculate scores for calibration and cross-validation
score_c = r2_score(y_df, y_c)
score_cv = r2_score(y_df, y_cv)
# Calculate mean square error for calibration and cross validation

mse_c = mean_squared_error(y_df, y_c)
mse_cv = mean_squared_error(y_df, y_cv)

print(score_c, score_cv)
print(mse_c, mse_cv)
# Out:
# 0.9848340523115449 -15.14649505941636
# 0.020707936081303502 22.046798162306988

# %% [markdown]
# now using PCA with Linear regression and PLS

# %%
n_components=25

x = X_train
x_t = X_test
print(x.shape)
print(x[1].shape)
print(len(x))


# This has to be used later for regression, PCA is done on X only
"""
y_df = pd.read_csv('labels_aligned+.csv', sep = ',')
concentration=y_df.values
#print(concentration)
multi_y = concentration[:,2:]
#print (multi_y)
print (multi_y.shape)
multi_y= np.array(multi_y, dtype=np.float)
y=np.around(multi_y, decimals=4)
#print(y)
"""

# PCA

X_std = StandardScaler().fit_transform(x)
X_std_test = StandardScaler().fit_transform(x_t)
#print(X_std)

pca = PCA(n_components= n_components)
PC=pca.fit(X_std)

x_pc = pca.fit_transform(X_std)
x_test1 = pca.transform(X_std_test)
print(x_pc.shape)
#principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 'principal component 3'])
#print(principalDf)


#print(pca.explained_variance_ratio_)
print(np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100))
# Out:
# (19, 29)
# (29,)
# 19
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-8230970e06b0> in <module>
#      28
#      29 pca = PCA(n_components= n_components)
# ---> 30 PC=pca.fit(X_std)
#      31
#      32 x_pc = pca.fit_transform(X_std)
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     342             Returns the instance itself.
#     343         """
# --> 344         self._fit(X)
#     345         return self
#     346
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     414         # Call different fits for either full or truncated SVD
#     415         if self._fit_svd_solver == 'full':
# --> 416             return self._fit_full(X, n_components)
#     417         elif self._fit_svd_solver in ['arpack', 'randomized']:
#     418             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# ~\.conda\envs\tf_env\lib\site-packages\sklearn\decomposition\_pca.py in _fit_full(self, X, n_components)
#     433                              "min(n_samples, n_features)=%r with "
#     434                              "svd_solver='full'"
# --> 435                              % (n_components, min(n_samples, n_features)))
#     436         elif n_components >= 1:
#     437             if not isinstance(n_components, numbers.Integral):
#
# ValueError: n_components=25 must be between 0 and min(n_samples, n_features)=19 with svd_solver='full'

# %%
regr = linear_model.LinearRegression()
# Fit
regr.fit(x_pc, y_train)
# Calibration
y_p = regr.predict(x_test1)
# Cross-validation
#y_cv = cross_val_predict(regr, principalComponents, y_df, cv=10)
# Calculate scores for calibration and cross-validation
score_c = r2_score(y_test, y_p)
#score_cv = r2_score(y_df, y_cv)
# Calculate mean square error for calibration and cross validation
mse_c = mean_squared_error(y_test, y_p)
#mse_cv = mean_squared_error(y_df, y_cv)

print("R2_pred: ", score_c)
print("MSE: ", mse_c)
# Out:
# R2_pred:  0.5193224597834807
# MSE:  1.2581312388016068

# %%
optimise_pls_cv(x_pc, y_train, 15, plot_components=True)
# Out:
# 37% completed
# Suggested number of components:  2
# R2 calib: 0.969
# R2 CV: 0.099
# MSE calib: 0.030
# MSE CV: 0.872

# %%
pls = PLSRegression(n_components=2)
# Fit
pls.fit(x_pc, y_train)
# Calibration
y_c = pls.predict(x_test1)
# Cross-validation
#y_cv = cross_val_predict(regr, principalComponents, y_df, cv=10)
# Calculate scores for calibration and cross-validation
score_c = r2_score(y_test, y_c)
#score_cv = r2_score(y_df, y_cv)
# Calculate mean square error for calibration and cross validation
mse_c = mean_squared_error(y_test, y_c)
#mse_cv = mean_squared_error(y_df, y_cv)

print("R2_pred: ", score_c)
print("MSE: ", mse_c)
# Out:
# R2_pred:  0.5193224597834794
# MSE:  1.2581312388016104

# %% [markdown]
# # Partial Least Square Regression

# %%
print(wl.shape)
# Out:
# (1446,)

# %% [markdown]
# ## Wavelenght selection for PLS

# %%
start_time = time.time()

opt_Xc, ncomp, wav, sorted_ind = pls_variable_selection(x_df.values, y_val, 15)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 100% completed
# Optimised number of PLS components:  8
# Wavelengths to be discarded  1411
# Optimised MSEP  0.39322839374148005
#
# --- 341.1094193458557 seconds ---

# %%
#print(opt_Xc.shape,"\n")
#print("sorted indexes: ", sorted_ind)
print("sorted wavelengths: ", wl[sorted_ind[:10]].T)

plt.plot(opt_Xc.T)
plt.show()
# Out:
# sorted wavelengths:  [309.506  399.4131 382.791  291.0649 377.5265 383.387  334.0345 275.32
#  333.6584 383.9826]

# %%
X_train, X_test, y_train, y_test = train_test_split(x_selecta, y_df, test_size=0.2, random_state = 3) #seed for Mg = 3, 16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Si = 7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 16) #seed for Cu =16
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 7) #seed for Fe =7
#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2, random_state = 3) #seed for Mn = 3

#X_train, X_test, y_train, y_test = train_test_split(opt_Xc, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print(y_test)
# Out:
# (19, 87) (19, 1)
# (5, 87) (5, 1)
#        0
# 22  1.11
# 12  0.32
# 17  0.39
# 15  4.54
# 14  0.77

# %%
optimise_pls_cv(X_train,y_train, 40, plot_components=True)
# Out:
# 100% completed
# Suggested number of components:  1
# R2 calib: 0.207
# R2 CV: -0.638
# MSE calib: 0.819
# MSE CV: 1.690

# %%
# Define PLS object
pls = PLSRegression(n_components=1)
# Fit
pls.fit(X_train, y_train)

y_pred = pls.predict(X_test)
y_pred1 = pls.predict(X_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")


c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  -0.5019501966917148
# RMSE:  1.9395877766841056

# %% [markdown]
# ## Using Normalization

# %%
Xn_train = normalize(X_train, axis=1)
Xn_test = normalize(X_test, axis=1)
print(Xn_train.shape)
print(Xn_test.shape)
# Out:
# (19, 87)
# (5, 87)

# %%
plt.plot(Xn_train.T)
plt.show()

# %%
#optimise_pls_cv(Xn_train,y_train, 40, plot_components=True)
#optimise_pls_cv(Xn_train,y_train, 7, plot_components=True)

# %%
# Define PLS object
pls = PLSRegression(n_components=14)
# Fit
pls.fit(Xn_train, y_train)

y_pred = pls.predict(Xn_test)
y_pred1 = pls.predict(Xn_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")


b=np.append(y_test, y_pred, axis=1)

print("TEST\n [real, predictions]")
print(b)
print("")

c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  0.09133829244281
# RMSE:  1.5086301601232908
#
# TEST
#  [real, predictions]
# [[ 1.11        1.99336033]
#  [ 0.32       -0.58641393]
#  [ 0.39        0.32008509]
#  [ 4.54        1.41449478]
#  [ 0.77        0.83513196]]

# %% [markdown]
# ## Using SNV

# %%
Xs_train = snv(X_train)
Xs_test = snv(X_test)
print(Xs_train.shape)
print(Xs_test.shape)

#optimise_pls_cv(Xn_train,y_train, 40, plot_components=True)
#optimise_pls_cv(Xs_train,y_train, 7, plot_components=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-774bae2e5c25> in <module>
# ----> 1 Xs_train = snv(X_train)
#       2 Xs_test = snv(X_test)
#       3 print(Xs_train.shape)
#       4 print(Xs_test.shape)
#       5
#
# <ipython-input-5-ac3f06072fd6> in snv(input_data)
#       5     for i in range(input_data.shape[0]):
#       6         # Apply correction
# ----> 7         data_snv[i,:] = (input_data[i,:] - np.mean(input_data[i,:])) / np.std(input_data[i,:])
#       8     return data_snv
#
# ~\.conda\envs\tf_env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~\.conda\envs\tf_env\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# ~\.conda\envs\tf_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0, slice(None, None, None))' is an invalid key

# %%
plt.plot(Xs_train.T)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-39e5e1589ac8> in <module>
# ----> 1 plt.plot(Xs_train.T)
#       2 plt.show()
#
# NameError: name 'Xs_train' is not defined

# %%
# Define PLS object
pls = PLSRegression(n_components=14)
# Fit
pls.fit(Xs_train, y_train)

y_pred = pls.predict(Xs_test)
y_pred1 = pls.predict(Xs_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")


b=np.append(y_test, y_pred, axis=1)

print("TEST\n [real, predictions]")
print(b)
print("")

c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-47b7cdf7834f> in <module>
#       2 pls = PLSRegression(n_components=14)
#       3 # Fit
# ----> 4 pls.fit(Xs_train, y_train)
#       5
#       6 y_pred = pls.predict(Xs_test)
#
# NameError: name 'Xs_train' is not defined

# %% [markdown]
# ## Using Max-norm

# %%
Xm_train = X_train / np.max(X_train)
Xm_test = X_test / np.max(X_test)

#optimise_pls_cv(Xn_train,y_train, 40, plot_components=True)
#optimise_pls_cv(Xm_train,y_train, 15, plot_components=True)

# %%
plt.plot(Xm_train.T)
plt.show()

# %%
# Define PLS object
pls = PLSRegression(n_components=14)
# Fit
pls.fit(Xm_train, y_train)

y_pred = pls.predict(Xm_test)
y_pred1 = pls.predict(Xm_train)

# Calculate score and error
r2 = r2_score(y_test, y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))


print("R2_pred: ", r2)
print("RMSE: ", rmse)
#print("R2_cv: ",score_cv)
print("")

b=np.append(y_test, y_pred, axis=1)

print("TEST\n [real, predictions]")
print(b)
print("")

c=np.append(y_train, y_pred1, axis=1)

#print("TRAIN\n [real, predictions]")
#print(c)

plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.scatter(y_train, y_pred1)
plt.plot( y_test, linear_model.LinearRegression().fit(y_test, y_pred).predict(y_test) )
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  -51.58768214648942
# RMSE:  11.47687593948486
#
# TEST
#  [real, predictions]
# [[ 1.11        9.77982254]
#  [ 0.32        3.05023428]
#  [ 0.39       11.83769103]
#  [ 4.54       17.68837502]
#  [ 0.77       17.26375667]]

# %% [markdown]
# ## Using Savgol filter

# %%
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
#print(X_test)
# Out:
# (19, 1446) (19, 1)
# (5, 1446) (5, 1)

# %%
# Calculate second derivative
X2 = savgol_filter(opt_Xc, 11, polyorder = 6,deriv=0) # Is this useful with LIBS spectra???
# Plot second derivative
plt.figure(figsize=(8,4.5))
with plt.style.context(('ggplot')):
    plt.plot(range(len(X2.T)), X2.T)
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('D2 Intensity')
    plt.show()
    

    
optimise_pls_cv(X2, y_df, 40, plot_components=True)
# Out:
# 100% completed
# Suggested number of components:  8
# R2 calib: 0.956
# R2 CV: 0.404
# MSE calib: 0.060
# MSE CV: 0.813

# %%
X2_train = savgol_filter(X_train, 37, polyorder = 4,deriv=1) 
X2_test = savgol_filter(X_test, 35, polyorder = 4,deriv=1) 




optimise_pls_cv(X2_train, y_train, 40, plot_components=True)
# Out:
# 100% completed
# Suggested number of components:  1
# R2 calib: 0.169
# R2 CV: -0.027
# MSE calib: 1.211
# MSE CV: 1.497

# %%
# Define PLS object
pls = PLSRegression(n_components=4)
# Fit
pls.fit(X2_train, y_train)

y_pred = pls.predict(X2_test)

# Cross-validation
y_cv = cross_val_predict(pls, X2_train, y_train, cv=10)

# Calculate scores for calibration and cross-validation
score_pred = r2_score(y_test, y_pred)
score_cv = r2_score(y_train, y_cv)

print("R2_pred: ", score_pred)
print("R2_cv: ",score_cv)
print("")

b=np.append(y_test, y_pred, axis=1)

print("[real, predictions]")
print(b)

plt.scatter(y_test, y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()
# Out:
# R2_pred:  -2586.547461785336
# R2_cv:  -0.690675692387712
#
# [real, predictions]
# [[ 3.90000000e-01 -4.48737877e+01]
#  [ 2.93000000e-01 -4.61390595e+01]
#  [ 2.50000000e-02 -3.88958047e+01]
#  [ 2.48000000e+00 -4.94609327e+01]
#  [ 3.20000000e-01 -4.45219137e+01]]

# %% [markdown]
# # Elastic Net

# %%
alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]

# %%
for a in alphas:
    model = ElasticNet(alpha=a).fit(X_train,y_train)   
    score = model.score(X_train, y_train)
    pred_y = model.predict(X_test)
    mse = mean_squared_error(y_test, pred_y)   
    print("Alpha:{0:.4f}, R2:{1:.2f}, MSE:{2:.2f}, RMSE:{3:.2f}".format(a, score, mse, np.sqrt(mse)))
# Out:
# Alpha:0.0001, R2:1.00, MSE:0.81, RMSE:0.90
# Alpha:0.0010, R2:1.00, MSE:0.81, RMSE:0.90
# Alpha:0.0100, R2:1.00, MSE:0.85, RMSE:0.92
# Alpha:0.1000, R2:1.00, MSE:1.33, RMSE:1.15
# Alpha:0.3000, R2:1.00, MSE:1.28, RMSE:1.13
# Alpha:0.5000, R2:0.99, MSE:1.29, RMSE:1.14
# Alpha:0.7000, R2:0.99, MSE:1.31, RMSE:1.14
# Alpha:1.0000, R2:0.97, MSE:1.37, RMSE:1.17

# %%
model = ElasticNet(alpha=0.0001).fit(X_train,y_train)   
score = model.score(X_train, y_train)
print("Train score: ", score)
pred_y = model.predict(X_test)


rmse = sqrt(mean_squared_error(y_test, pred_y))
r2 = r2_score(y_test, pred_y)
print("RMSE: ", rmse)
print("R^2: ", r2)
# Out:
# Train score:  0.9999997468092139
# RMSE:  0.8973216240711588
# R^2:  0.6923732114755278

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.grid(True)
plt.show()

# %% [markdown]
# # Random Forest

# %%
#X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.15)
X_train, X_test, y_train, y_test = train_test_split(principalComponents, y_df, test_size=0.15)


print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
#print(y_test)
# Out:
# (20, 20) (20, 1)
# (4, 20) (4, 1)

# %%
y_test=np.ravel(y_test)
print(y_test.shape)
y_train=np.ravel(y_train)
print(y_train.shape)
# Out:
# (5,)
# (19,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 250, max_depth=30, random_state = 42)
# Train the model on training data

rf.fit(X_train, y_train);

# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

rmse = sqrt(mean_squared_error(y_test, predictions))
r2 = r2_score(y_test, predictions)
print("RMSE: ", rmse)
print("R^2: ", r2, "\n")

y_test= y_test.reshape((len(y_test), 1))
predictions=predictions.reshape((len(y_test), 1))
#print((y_test, predictions))

b=np.append(y_test, predictions, axis=1)

print("[real, predictions]")
print(b)

plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# RMSE:  1.685941129529736
# R^2:  -0.08595716627220162
#
# [real, predictions]
# [[0.52     0.695264]
#  [0.391    0.669912]
#  [4.54     0.838584]
#  [2.03     1.827152]
#  [0.32     0.92154 ]]
# Text(0, 0.5, 'Predictions')

# %% [markdown]
# # MultiOutput Random Forest

# %%
multi_y = concentration[:,1:-2]
print (multi_y.shape)
print (type(multi_y))
df_y= pd.DataFrame(multi_y)
print (type(df_y))
# Out:
# (24, 6)
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %%
X_train, X_test, y_train, y_test = train_test_split(x_df, df_y, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
#print(X_test)
# Out:
# (19, 1130) (19, 6)
# (5, 1130) (5, 6)

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor

max_depth = 30
regr_multirf = MultiOutputRegressor(RandomForestRegressor(n_estimators=650,
                                                          max_depth=max_depth,
                                                          random_state=0))
regr_multirf.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(bootstrap=True,
#                                                      ccp_alpha=0.0,
#                                                      criterion='mse',
#                                                      max_depth=30,
#                                                      max_features='auto',
#                                                      max_leaf_nodes=None,
#                                                      max_samples=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=1,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators=650,
#                                                      n_jobs=None,
#                                                      oob_score=False,
#                                                      random_state=0, verbose=0,
#                                                      warm_start=False),
#                      n_jobs=None)

# %%
y_multirf = regr_multirf.predict(X_test)

# %%
print(y_test.shape)
print(y_multirf.shape)
# Out:
# (5, 6)
# (5, 6)

# %%
rmse = sqrt(mean_squared_error(y_test, y_multirf))
r2 = r2_score(y_test, y_multirf)

print("R^2: ", r2)
print("RMSE: ", rmse)
# Out:
# R^2:  -1.2798201186343863
# RMSE:  1.5231794557929577

# %%
b=np.append(np.around(y_test,3), np.around(y_multirf,3), axis=1)

print("[real, predictions]")
print(b)
# Out:
# [real, predictions]
# [[6.160e+00 0.000e+00 3.630e-01 0.000e+00 6.000e-03 2.060e-01 8.711e+00
#   2.880e-01 4.460e-01 2.870e-01 7.790e-01 1.910e-01]
#  [6.120e+00 0.000e+00 3.200e-01 0.000e+00 5.000e-03 1.600e-02 8.009e+00
#   2.150e-01 4.630e-01 8.500e-02 1.110e-01 1.440e-01]
#  [1.253e+01 3.100e-01 2.500e-02 5.000e-02 5.600e-02 3.300e-02 7.822e+00
#   2.570e-01 2.970e-01 1.650e-01 1.750e-01 2.170e-01]
#  [1.800e-01 5.000e-01 1.110e+00 5.200e-02 1.500e-01 1.260e+00 4.830e-01
#   3.630e-01 1.233e+00 2.260e-01 1.360e-01 9.710e-01]
#  [1.290e+01 1.200e-01 5.200e-01 1.550e-01 5.200e-01 2.860e-01 6.898e+00
#   3.360e-01 7.140e-01 1.420e-01 5.610e-01 2.290e-01]]

# %%
plt.scatter(y_test, y_multirf)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
y_pred=np.around(y_multirf,2)
y_pred[:,0]
# Out:
# array([8.71, 8.01, 7.82, 0.48, 6.9 ])

# %%
y_test[0].values
# Out:
# array([ 6.16,  6.12, 12.53,  0.18, 12.9 ])

# %%
print("real: ", y_test[0].values)
print("pred: ", y_pred[:,0])
# Out:
# real:  [ 6.16  6.12 12.53  0.18 12.9 ]
# pred:  [8.71 8.01 7.82 0.48 6.9 ]

# %% [markdown]
# # PLS-2

# %%
optimise_pls_cv(X_train, y_train, 40, plot_components=True)
# Out:
# 100% completed
# Suggested number of components:  33
# R2 calib: 1.000
# R2 CV: 0.018
# MSE calib: 0.000
# MSE CV: 0.939

# %%
# Define PLS object
pls = PLSRegression(n_components= 26)
# Fit
pls.fit(X_train, y_train)
# Cross-validation
y_cv = cross_val_predict(pls, X_train, y_train, cv=10)
# Calculate scores
score = r2_score(y_train, y_cv)
mse = mean_squared_error(y_train, y_cv)

print("R^2: ", score)
print("MSE: ", mse)
# Out:
# R^2:  0.018347253779067135
# MSE:  0.9391318844120397

# %%
y_pred = pls.predict(X_test)

# Cross-validation
y_cv = cross_val_predict(pls, X_train, y_train, cv=10)

# Calculate scores for calibration and cross-validation
score_pred = r2_score(y_test, y_pred)
score_cv = r2_score(y_train, y_cv)

print(score_pred) #NAMMERDA
print(score_cv)
# Out:
# -4.070272705754876
# 0.36555579763038115

# %%
pd.DataFrame(np.round(y_pred, decimals=2))
# Out:
#        0     1     2     3     4     5
# 0   7.84  0.22  0.54  0.19  0.57  0.27
# 1   8.62  0.12  0.35  0.06 -0.12 -0.06
# 2  10.50  0.13 -0.61  0.45  0.15 -0.03
# 3  -0.28  0.42  1.56 -0.11 -0.34  0.95
# 4   9.93  0.09  0.29 -0.26  0.65  0.14

# %%
np.round(y_test, decimals=2)
# Out:
#         0     1     2     3     4     5
# 20   6.16  0.00  0.36  0.00  0.01  0.21
# 12   6.12  0.00  0.32  0.00  0.01  0.02
# 13  12.53  0.31  0.02  0.05  0.06  0.03
# 22   0.18  0.50  1.11  0.05  0.15  1.26
# 7   12.90  0.12  0.52  0.16  0.52  0.29
