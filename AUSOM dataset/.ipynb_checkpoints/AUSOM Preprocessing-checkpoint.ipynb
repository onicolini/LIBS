# %%
import os
from sys import stdout
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import peakutils

import matplotlib
#%matplotlib notebook
#%matplotlib inline
#matplotlib.use('nbagg')
#import mpld3
#mpld3.enable_notebook()

from math import sqrt
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict

import numpy as np
from numpy.linalg import norm
from scipy import sparse
from scipy.sparse.linalg import spsolve
from scipy.signal import savgol_filter
import scipy.io

import warnings
warnings.filterwarnings('ignore')

# %%
def drPLS(x_input,y_input, **kwargs):
    """
    drPLS: (automatic) Baseline correction method based on doubly reweighted penalized least squares.
    Xu et al., Applied Optics 58(14):3913-3920.
    
    Allows subtracting a baseline under a x y spectrum.
    
    Parameters
    ----------
    x_input : ndarray
        x values.
    
    y_input : ndarray
        y values.
        
    kwargs:  #optional parameters
        niter = kwargs.get('niter',100)
        lam = kwargs.get('lam',1000000)
        eta = kwargs.get('eta',0.5)
        ratio = kwargs.get('ratio',0.001)

    Returns
    -------
    out1 : ndarray
        Contain the corrected signal.
    out2 : ndarray
        Contain the baseline.
    """
    # we get the signals in the bir
    # yafit_unscaled = get_portion_interest(x_input,y_input,bir)

    # signal standard standardization with sklearn
    # this helps for polynomial fitting
    X_scaler = StandardScaler().fit(x_input.reshape(-1, 1))
    Y_scaler = StandardScaler().fit(y_input.reshape(-1, 1))

    # transformation
    x = X_scaler.transform(x_input.reshape(-1, 1))
    y = Y_scaler.transform(y_input.reshape(-1, 1))

    #yafit = np.copy(yafit_unscaled)
    #yafit[:,0] = X_scaler.transform(yafit_unscaled[:,0].reshape(-1, 1))[:,0]
    #yafit[:,1] = Y_scaler.transform(yafit_unscaled[:,1].reshape(-1, 1))[:,0]

    y = y.reshape(len(y_input))    
    
    #according to Applied Optics, 2019, 58, 3913-3920.

    #optional parameters
    niter = kwargs.get('niter',100)
    lam = kwargs.get('lam',1000000)
    eta = kwargs.get('eta',0.5)
    ratio = kwargs.get('ratio',0.001)

    #optional smoothing in the next line, currently commented out
    #y = np.around(savgol_filter(raw_data,19,2,deriv=0,axis=1),decimals=6)

    L = len(y)

    D = sparse.diags([1,-2,1],[0,-1,-2],shape=(L,L-2),format='csr')
    D = D.dot(D.transpose())
    D_1 = sparse.diags([-1,1],[0,-1],shape=(L,L-1),format='csr')
    D_1 = D_1.dot(D_1.transpose())

    w_0 = np.ones(L)
    I_n = sparse.diags(w_0,format='csr')

    #this is the code for the fitting procedure
    w = w_0
    W = sparse.diags(w,format='csr')
    Z = w_0

    for jj in range(int(niter)):
        W.setdiag(w)
        Z_prev = Z
        Z = sparse.linalg.spsolve(W + D_1 + lam * (I_n - eta*W) * D,W*y,permc_spec='NATURAL')
        if np.linalg.norm(Z - Z_prev) > ratio:
            d = y - Z
            d_negative = d[d<0]
            sigma_negative = np.std(d_negative)
            mean_negative = np.mean(d_negative)
            w = 0.5 * (1 - np.exp(jj) * (d - (-mean_negative + 2*sigma_negative))/sigma_negative / (1 + np.abs(np.exp(jj) * (d - (-mean_negative + 2*sigma_negative))/sigma_negative)))
        else:
            break
    #end of fitting procedure

    baseline_fitted = Z

    return y_input.reshape(-1,1)-Y_scaler.inverse_transform(baseline_fitted.reshape(-1, 1)), Y_scaler.inverse_transform(baseline_fitted.reshape(-1, 1))

# %%
def snv(input_data):
  
    # Define a new array and populate it with the corrected data  
    data_snv = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
        # Apply correction
        data_snv[i,:] = (input_data[i,:] - np.mean(input_data[i,:])) / np.std(input_data[i,:])
    return data_snv

# %%
def msc(input_data, reference=None):
    ''' Perform Multiplicative scatter correction'''
    # mean centre correction
    for i in range(input_data.shape[0]):
        input_data[i,:] -= input_data[i,:].mean()
    # Get the reference spectrum. If not given, estimate it from the mean    
    if reference is None:    
        # Calculate mean
        ref = np.mean(input_data, axis=0)
    else:
        ref = reference
    # Define a new array and populate it with the corrected data    
    data_msc = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
        # Run regression
        fit = np.polyfit(ref, input_data[i,:], 1, full=True)
        # Apply correction
        data_msc[i,:] = (input_data[i,:] - fit[0][1]) / fit[0][0] 
    return (data_msc, ref)

# %%
mat = scipy.io.loadmat("./data/120.mat")
data = mat["data"]
wl = mat["wl"]

# %%
print(wl[-1])
print(wl.shape)
print(data.shape)
# Out:
# [429.8218]
# (2047, 1)
# (2047, 53)

# %%
# %matplotlib notebook
plt.plot(wl, data[:,21])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#for i in range(len(data[0])):
#    print(max(data[:,i]))

# %%
print(len(data[0]))
# Out:
# 60

# %%
from glob import glob

filenames = glob('./data/*')

dfs = [scipy.io.loadmat(f) for f in filenames]
print(type(dfs)) #dfs is a list of mat files 
print(len(dfs)) #dfs is a list of mat files
# Out:
# <class 'list'>
# 233

# %%
print(data[:,-1].shape)
print(data[-1].shape)
print(len(data))
print(len(data[0]))
print(data.shape)
print(wl.shape)
# Out:
# (2047,)
# (60,)
# 2047
# 60
# (2047, 60)
# (2047, 1)

# %%
# %matplotlib notebook
plt.plot(wl, data[:,20])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
orig= data[:,10]

corrected, x1= drPLS(wl, orig, lam= 10e7) #lambda

print(x1.shape)

# %matplotlib notebook
#plt.plot(wl, orig)
#plt.plot(wl, x1)
plt.plot(wl, corrected)
plt.show()

print(orig.reshape(1,-1).shape)
print(corrected.shape)
# Out:
# (2047, 1)
# <img src="data:image/png;base64,..." width="640">
# (1, 2047)
# (2047, 1)

# %%
#a, b = msc((pd.DataFrame(corrected).dropna()).values)
#a =  orig / np.sum(orig,axis=0)
b =  corrected / np.max(corrected,axis=0)
c = normalize (corrected.reshape(1, -1))
#a = snv(orig.reshape(1,-1))
a = StandardScaler().fit_transform(corrected.reshape(-1, 1))

print(a.shape)
print(wl.shape)

# %matplotlib notebook
#plt.plot(wl, corrected)
plt.plot(wl, a)
#plt.plot(wl, b)
#plt.plot(wl, c.T)
plt.show()
# Out:
# (2047, 1)
# (2047, 1)
# <img src="data:image/png;base64,..." width="640">

# %%
for j in range(0, len(dfs)): #loop over all .mat files
    mat = dfs[j]
    wl= mat["wl"]
    data = mat["data"]
    print("data index: " + str(j))
    print("max: ",np.max(data))
    #print("data " + str(j) + " shape: ", data.shape)
    #print("wl " + str(j) + " shape: ", wl.shape)
    #print("wl[0] " + str(wl[0]) + ", wl[-1] " + str(wl[-1]))
    print("")
# Out:
# data index: 0
# max:  65535
#
# data index: 1
# max:  65535
#
# data index: 2
# max:  65535
#
# data index: 3
# max:  65535
#
# data index: 4
# max:  65535
#
# data index: 5
# max:  65535
#
# data index: 6
# max:  65535
#
# data index: 7
# max:  65535
#
# data index: 8
# max:  65535
#
# data index: 9
# max:  57013
#
# data index: 10
# max:  65535
#
# data index: 11
# max:  65535
#
# data index: 12
# max:  60150
#
# data index: 13
# max:  65535
#
# data index: 14
# max:  65535
#
# data index: 15
# max:  65535
#
# data index: 16
# max:  65535
#
# data index: 17
# max:  65535
#
# data index: 18
# max:  60008
#
# data index: 19
# max:  60866
#
# data index: 20
# max:  65535
#
# data index: 21
# max:  65535
#
# data index: 22
# max:  65535
#
# data index: 23
# max:  65096
#
# data index: 24
# max:  65535
#
# data index: 25
# max:  65535
#
# data index: 26
# max:  65535
#
# data index: 27
# max:  65535
#
# data index: 28
# max:  65535
#
# data index: 29
# max:  65535
#
# data index: 30
# max:  65535
#
# data index: 31
# max:  64718
#
# data index: 32
# max:  65535
#
# data index: 33
# max:  65535
#
# data index: 34
# max:  40575
#
# data index: 35
# max:  60724
#
# data index: 36
# max:  65535
#
# data index: 37
# max:  65535
#
# data index: 38
# max:  65535
#
# data index: 39
# max:  65535
#
# data index: 40
# max:  65535
#
# data index: 41
# max:  49879
#
# data index: 42
# max:  65535
#
# data index: 43
# max:  65535
#
# data index: 44
# max:  65535
#
# data index: 45
# max:  63242
#
# data index: 46
# max:  65535
#
# data index: 47
# max:  65535
#
# data index: 48
# max:  58885
#
# data index: 49
# max:  65535
#
# data index: 50
# max:  60302
#
# data index: 51
# max:  65535
#
# data index: 52
# max:  65535
#
# data index: 53
# max:  65535
#
# data index: 54
# max:  65535
#
# data index: 55
# max:  65535
#
# data index: 56
# max:  41586
#
# data index: 57
# max:  44393
#
# data index: 58
# max:  65535
#
# data index: 59
# max:  65535
#
# data index: 60
# max:  57670
#
# data index: 61
# max:  65535
#
# data index: 62
# max:  65535
#
# data index: 63
# max:  65535
#
# data index: 64
# max:  65535
#
# data index: 65
# max:  65535
#
# data index: 66
# max:  65535
#
# data index: 67
# max:  65535
#
# data index: 68
# max:  65535
#
# data index: 69
# max:  65535
#
# data index: 70
# max:  65535
#
# data index: 71
# max:  65535
#
# data index: 72
# max:  58748
#
# data index: 73
# max:  65535
#
# data index: 74
# max:  65535
#
# data index: 75
# max:  65535
#
# data index: 76
# max:  65535
#
# data index: 77
# max:  65535
#
# data index: 78
# max:  65535
#
# data index: 79
# max:  65535
#
# data index: 80
# max:  65535
#
# data index: 81
# max:  65535
#
# data index: 82
# max:  65535
#
# data index: 83
# max:  51666
#
# data index: 84
# max:  65535
#
# data index: 85
# max:  65535
#
# data index: 86
# max:  65535
#
# data index: 87
# max:  65535
#
# data index: 88
# max:  65535
#
# data index: 89
# max:  65535
#
# data index: 90
# max:  65535
#
# data index: 91
# max:  65535
#
# data index: 92
# max:  65535
#
# data index: 93
# max:  65535
#
# data index: 94
# max:  65535
#
# data index: 95
# max:  65535
#
# data index: 96
# max:  65535
#
# data index: 97
# max:  65535
#
# data index: 98
# max:  65535
#
# data index: 99
# max:  65535
#
# data index: 100
# max:  65535
#
# data index: 101
# max:  65535
#
# data index: 102
# max:  65535
#
# data index: 103
# max:  65535
#
# data index: 104
# max:  65535
#
# data index: 105
# max:  65535
#
# data index: 106
# max:  65535
#
# data index: 107
# max:  65535
#
# data index: 108
# max:  65535
#
# data index: 109
# max:  65535
#
# data index: 110
# max:  65535
#
# data index: 111
# max:  65535
#
# data index: 112
# max:  65535
#
# data index: 113
# max:  65535
#
# data index: 114
# max:  65535
#
# data index: 115
# max:  56328
#
# data index: 116
# max:  65535
#
# data index: 117
# max:  51120
#
# data index: 118
# max:  65535
#
# data index: 119
# max:  65535
#
# data index: 120
# max:  56524
#
# data index: 121
# max:  57078
#
# data index: 122
# max:  65535
#
# data index: 123
# max:  65535
#
# data index: 124
# max:  65535
#
# data index: 125
# max:  65535
#
# data index: 126
# max:  65535
#
# data index: 127
# max:  65535
#
# data index: 128
# max:  65535
#
# data index: 129
# max:  65535
#
# data index: 130
# max:  65535
#
# data index: 131
# max:  65535
#
# data index: 132
# max:  65535
#
# data index: 133
# max:  65535
#
# data index: 134
# max:  65535
#
# data index: 135
# max:  55816
#
# data index: 136
# max:  43463
#
# data index: 137
# max:  65535
#
# data index: 138
# max:  54092
#
# data index: 139
# max:  65535
#
# data index: 140
# max:  65535
#
# data index: 141
# max:  41775
#
# data index: 142
# max:  64722
#
# data index: 143
# max:  65535
#
# data index: 144
# max:  65535
#
# data index: 145
# max:  65535
#
# data index: 146
# max:  65535
#
# data index: 147
# max:  65535
#
# data index: 148
# max:  65535
#
# data index: 149
# max:  65535
#
# data index: 150
# max:  65535
#
# data index: 151
# max:  46657
#
# data index: 152
# max:  52727
#
# data index: 153
# max:  65535
#
# data index: 154
# max:  65535
#
# data index: 155
# max:  65535
#
# data index: 156
# max:  65535
#
# data index: 157
# max:  45273
#
# data index: 158
# max:  45355
#
# data index: 159
# max:  65535
#
# data index: 160
# max:  65535
#
# data index: 161
# max:  65535
#
# data index: 162
# max:  65535
#
# data index: 163
# max:  65424
#
# data index: 164
# max:  65535
#
# data index: 165
# max:  65535
#
# data index: 166
# max:  65535
#
# data index: 167
# max:  56588
#
# data index: 168
# max:  65535
#
# data index: 169
# max:  65535
#
# data index: 170
# max:  65535
#
# data index: 171
# max:  65535
#
# data index: 172
# max:  32381
#
# data index: 173
# max:  47588
#
# data index: 174
# max:  65535
#
# data index: 175
# max:  51846
#
# data index: 176
# max:  65535
#
# data index: 177
# max:  65535
#
# data index: 178
# max:  65535
#
# data index: 179
# max:  65535
#
# data index: 180
# max:  65535
#
# data index: 181
# max:  65535
#
# data index: 182
# max:  65535
#
# data index: 183
# max:  65535
#
# data index: 184
# max:  65535
#
# data index: 185
# max:  65535
#
# data index: 186
# max:  41880
#
# data index: 187
# max:  65535
#
# data index: 188
# max:  65535
#
# data index: 189
# max:  65535
#
# data index: 190
# max:  57025
#
# data index: 191
# max:  65535
#
# data index: 192
# max:  62618
#
# data index: 193
# max:  65535
#
# data index: 194
# max:  65535
#
# data index: 195
# max:  65535
#
# data index: 196
# max:  65535
#
# data index: 197
# max:  65409
#
# data index: 198
# max:  65535
#
# data index: 199
# max:  65535
#
# data index: 200
# max:  65535
#
# data index: 201
# max:  65535
#
# data index: 202
# max:  65535
#
# data index: 203
# max:  65535
#
# data index: 204
# max:  65535
#
# data index: 205
# max:  65535
#
# data index: 206
# max:  65535
#
# data index: 207
# max:  65535
#
# data index: 208
# max:  65535
#
# data index: 209
# max:  65535
#
# data index: 210
# max:  65535
#
# data index: 211
# max:  65535
#
# data index: 212
# max:  65535
#
# data index: 213
# max:  46781
#
# data index: 214
# max:  65535
#
# data index: 215
# max:  65535
#
# data index: 216
# max:  65535
#
# data index: 217
# max:  65535
#
# data index: 218
# max:  65535
#
# data index: 219
# max:  65535
#
# data index: 220
# max:  65535
#
# data index: 221
# max:  65535
#
# data index: 222
# max:  65535
#
# data index: 223
# max:  65535
#
# data index: 224
# max:  65535
#
# data index: 225
# max:  65535
#
# data index: 226
# max:  65535
#
# data index: 227
# max:  65535
#
# data index: 228
# max:  65535
#
# data index: 229
# max:  65535
#
# data index: 230
# max:  65535
#
# data index: 231
# max:  65535
#
# data index: 232
# max:  65535

# %%
len(wl)
wl[1046]
# Out:
# array([309.6334])

# %%
data.shape
# Out:
# (2047, 38)

# %% [markdown]
# For reference line normalization on Aluminium I should use

# %%
## THIS IS THE COMPLETE LOOP FOR DATA MANIPULATION

#print("the wavelength used for intensity filtering is: ", wl[1046]=309.6 nm)

print(len(dfs))

tot= np.empty((0, len(wl)))
print( "tot shape: " , tot.shape)

for j in range(0, len(dfs)): #loop over all .mat files
    mat = dfs[j]
    data = mat["data"]
    print("data index: " + str(j))
    print("data " + str(j) + " shape: ", data.shape)
    
    if(len(data) != len(wl)):
        data = data[:-1,:]
    
    count=0

    #result_array = np.empty_like(wl)
    
    tmp = np.empty((0, len(wl)))
    
    for i in (range(len(data[0])) ):
        
        orig= data[:,i]
        #corrected= data[:,i]
        
        #if ((max(orig)) < 65500):
        #if ((max(orig)) < 65500) and ((max(orig)) > 25500):
            
        corrected, x1= drPLS(wl, orig, lam= 10e7)
        #print(corrected.shape)

        #if corrected[1046] > 5500:
        #if corrected[1046] > 5500 and (max(orig)) < 65000:
        if max(corrected) > 10000 and (max(orig)) < 65000:
            count += 1
            
            #corrected = normalize (corrected.reshape(1, -1))
            #corrected=  snv(corrected.reshape(-1, 1))
            #corrected =  corrected / np.sum(corrected,axis=0)
            corrected =  corrected / np.max(corrected,axis=0)
            #corrected = corrected/corrected[1046]
            
            tmp = np.append(tmp, corrected.reshape(1, -1), axis=0)

            #print("a:", a.shape)
            #print("tmp:", tmp.shape)

    print("good spectra: ", count)
    print("tmp shape: ", tmp.shape)

    avg_arr= np.mean(tmp, axis=0).reshape((1, -1))
    print("avg array shape: " , avg_arr.shape, "\n")
    
    
    tot = np.append(tot, avg_arr, axis=0)

print(tot.shape)
# Out:
# 233
# tot shape:  (0, 2047)
# data index: 0
# data 0 shape:  (2047, 60)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 1
# data 1 shape:  (2047, 54)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 2
# data 2 shape:  (2047, 53)
# good spectra:  14
# tmp shape:  (14, 2047)
# avg array shape:  (1, 2047)
#
# data index: 3
# data 3 shape:  (2047, 44)
# good spectra:  15
# tmp shape:  (15, 2047)
# avg array shape:  (1, 2047)
#
# data index: 4
# data 4 shape:  (2047, 48)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 5
# data 5 shape:  (2047, 50)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 6
# data 6 shape:  (2047, 37)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 7
# data 7 shape:  (2047, 46)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 8
# data 8 shape:  (2047, 53)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 9
# data 9 shape:  (2047, 37)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 10
# data 10 shape:  (2047, 59)
# good spectra:  46
# tmp shape:  (46, 2047)
# avg array shape:  (1, 2047)
#
# data index: 11
# data 11 shape:  (2047, 52)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 12
# data 12 shape:  (2047, 84)
# good spectra:  45
# tmp shape:  (45, 2047)
# avg array shape:  (1, 2047)
#
# data index: 13
# data 13 shape:  (2047, 38)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 14
# data 14 shape:  (2047, 51)
# good spectra:  13
# tmp shape:  (13, 2047)
# avg array shape:  (1, 2047)
#
# data index: 15
# data 15 shape:  (2047, 48)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 16
# data 16 shape:  (2047, 47)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 17
# data 17 shape:  (2047, 43)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 18
# data 18 shape:  (2047, 57)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 19
# data 19 shape:  (2047, 50)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 20
# data 20 shape:  (2047, 44)
# good spectra:  20
# tmp shape:  (20, 2047)
# avg array shape:  (1, 2047)
#
# data index: 21
# data 21 shape:  (2047, 93)
# good spectra:  47
# tmp shape:  (47, 2047)
# avg array shape:  (1, 2047)
#
# data index: 22
# data 22 shape:  (2047, 43)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 23
# data 23 shape:  (2047, 52)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 24
# data 24 shape:  (2047, 33)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 25
# data 25 shape:  (2047, 38)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 26
# data 26 shape:  (2047, 67)
# good spectra:  37
# tmp shape:  (37, 2047)
# avg array shape:  (1, 2047)
#
# data index: 27
# data 27 shape:  (2047, 40)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 28
# data 28 shape:  (2047, 40)
# good spectra:  14
# tmp shape:  (14, 2047)
# avg array shape:  (1, 2047)
#
# data index: 29
# data 29 shape:  (2047, 32)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 30
# data 30 shape:  (2047, 53)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 31
# data 31 shape:  (2047, 47)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 32
# data 32 shape:  (2047, 72)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 33
# data 33 shape:  (2047, 100)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 34
# data 34 shape:  (2047, 36)
# good spectra:  18
# tmp shape:  (18, 2047)
# avg array shape:  (1, 2047)
#
# data index: 35
# data 35 shape:  (2047, 78)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 36
# data 36 shape:  (2047, 52)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 37
# data 37 shape:  (2047, 57)
# good spectra:  40
# tmp shape:  (40, 2047)
# avg array shape:  (1, 2047)
#
# data index: 38
# data 38 shape:  (2047, 45)
# good spectra:  11
# tmp shape:  (11, 2047)
# avg array shape:  (1, 2047)
#
# data index: 39
# data 39 shape:  (2047, 48)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 40
# data 40 shape:  (2047, 73)
# good spectra:  63
# tmp shape:  (63, 2047)
# avg array shape:  (1, 2047)
#
# data index: 41
# data 41 shape:  (2047, 76)
# good spectra:  56
# tmp shape:  (56, 2047)
# avg array shape:  (1, 2047)
#
# data index: 42
# data 42 shape:  (2047, 44)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 43
# data 43 shape:  (2047, 38)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 44
# data 44 shape:  (2047, 67)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 45
# data 45 shape:  (2047, 84)
# good spectra:  58
# tmp shape:  (58, 2047)
# avg array shape:  (1, 2047)
#
# data index: 46
# data 46 shape:  (2047, 100)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 47
# data 47 shape:  (2047, 54)
# good spectra:  43
# tmp shape:  (43, 2047)
# avg array shape:  (1, 2047)
#
# data index: 48
# data 48 shape:  (2047, 41)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 49
# data 49 shape:  (2047, 113)
# good spectra:  40
# tmp shape:  (40, 2047)
# avg array shape:  (1, 2047)
#
# data index: 50
# data 50 shape:  (2047, 69)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 51
# data 51 shape:  (2047, 74)
# good spectra:  39
# tmp shape:  (39, 2047)
# avg array shape:  (1, 2047)
#
# data index: 52
# data 52 shape:  (2047, 88)
# good spectra:  45
# tmp shape:  (45, 2047)
# avg array shape:  (1, 2047)
#
# data index: 53
# data 53 shape:  (2047, 47)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 54
# data 54 shape:  (2047, 47)
# good spectra:  18
# tmp shape:  (18, 2047)
# avg array shape:  (1, 2047)
#
# data index: 55
# data 55 shape:  (2047, 44)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 56
# data 56 shape:  (2047, 55)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 57
# data 57 shape:  (2047, 40)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 58
# data 58 shape:  (2047, 32)
# good spectra:  12
# tmp shape:  (12, 2047)
# avg array shape:  (1, 2047)
#
# data index: 59
# data 59 shape:  (2047, 39)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 60
# data 60 shape:  (2047, 42)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 61
# data 61 shape:  (2047, 55)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 62
# data 62 shape:  (2047, 75)
# good spectra:  44
# tmp shape:  (44, 2047)
# avg array shape:  (1, 2047)
#
# data index: 63
# data 63 shape:  (2047, 48)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 64
# data 64 shape:  (2047, 39)
# good spectra:  18
# tmp shape:  (18, 2047)
# avg array shape:  (1, 2047)
#
# data index: 65
# data 65 shape:  (2047, 57)
# good spectra:  38
# tmp shape:  (38, 2047)
# avg array shape:  (1, 2047)
#
# data index: 66
# data 66 shape:  (2047, 59)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 67
# data 67 shape:  (2047, 39)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 68
# data 68 shape:  (2047, 42)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 69
# data 69 shape:  (2047, 65)
# good spectra:  43
# tmp shape:  (43, 2047)
# avg array shape:  (1, 2047)
#
# data index: 70
# data 70 shape:  (2047, 41)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 71
# data 71 shape:  (2047, 58)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 72
# data 72 shape:  (2047, 35)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 73
# data 73 shape:  (2047, 45)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 74
# data 74 shape:  (2047, 42)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 75
# data 75 shape:  (2047, 40)
# good spectra:  22
# tmp shape:  (22, 2047)
# avg array shape:  (1, 2047)
#
# data index: 76
# data 76 shape:  (2047, 33)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 77
# data 77 shape:  (2047, 40)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 78
# data 78 shape:  (2047, 34)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 79
# data 79 shape:  (2047, 52)
# good spectra:  35
# tmp shape:  (35, 2047)
# avg array shape:  (1, 2047)
#
# data index: 80
# data 80 shape:  (2047, 58)
# good spectra:  22
# tmp shape:  (22, 2047)
# avg array shape:  (1, 2047)
#
# data index: 81
# data 81 shape:  (2047, 54)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 82
# data 82 shape:  (2047, 44)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 83
# data 83 shape:  (2047, 39)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 84
# data 84 shape:  (2047, 47)
# good spectra:  18
# tmp shape:  (18, 2047)
# avg array shape:  (1, 2047)
#
# data index: 85
# data 85 shape:  (2047, 46)
# good spectra:  20
# tmp shape:  (20, 2047)
# avg array shape:  (1, 2047)
#
# data index: 86
# data 86 shape:  (2047, 52)
# good spectra:  23
# tmp shape:  (23, 2047)
# avg array shape:  (1, 2047)
#
# data index: 87
# data 87 shape:  (2047, 38)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 88
# data 88 shape:  (2047, 79)
# good spectra:  50
# tmp shape:  (50, 2047)
# avg array shape:  (1, 2047)
#
# data index: 89
# data 89 shape:  (2047, 42)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 90
# data 90 shape:  (2047, 38)
# good spectra:  8
# tmp shape:  (8, 2047)
# avg array shape:  (1, 2047)
#
# data index: 91
# data 91 shape:  (2047, 57)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 92
# data 92 shape:  (2047, 26)
# good spectra:  11
# tmp shape:  (11, 2047)
# avg array shape:  (1, 2047)
#
# data index: 93
# data 93 shape:  (2047, 66)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 94
# data 94 shape:  (2047, 59)
# good spectra:  42
# tmp shape:  (42, 2047)
# avg array shape:  (1, 2047)
#
# data index: 95
# data 95 shape:  (2047, 91)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 96
# data 96 shape:  (2047, 45)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 97
# data 97 shape:  (2047, 73)
# good spectra:  40
# tmp shape:  (40, 2047)
# avg array shape:  (1, 2047)
#
# data index: 98
# data 98 shape:  (2047, 50)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 99
# data 99 shape:  (2047, 44)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 100
# data 100 shape:  (2047, 72)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 101
# data 101 shape:  (2047, 29)
# good spectra:  15
# tmp shape:  (15, 2047)
# avg array shape:  (1, 2047)
#
# data index: 102
# data 102 shape:  (2047, 48)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 103
# data 103 shape:  (2047, 44)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 104
# data 104 shape:  (2047, 44)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 105
# data 105 shape:  (2047, 49)
# good spectra:  35
# tmp shape:  (35, 2047)
# avg array shape:  (1, 2047)
#
# data index: 106
# data 106 shape:  (2047, 40)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 107
# data 107 shape:  (2047, 61)
# good spectra:  46
# tmp shape:  (46, 2047)
# avg array shape:  (1, 2047)
#
# data index: 108
# data 108 shape:  (2047, 49)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 109
# data 109 shape:  (2047, 61)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 110
# data 110 shape:  (2047, 65)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 111
# data 111 shape:  (2047, 83)
# good spectra:  51
# tmp shape:  (51, 2047)
# avg array shape:  (1, 2047)
#
# data index: 112
# data 112 shape:  (2047, 45)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 113
# data 113 shape:  (2047, 58)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 114
# data 114 shape:  (2047, 44)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 115
# data 115 shape:  (2047, 48)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 116
# data 116 shape:  (2047, 68)
# good spectra:  42
# tmp shape:  (42, 2047)
# avg array shape:  (1, 2047)
#
# data index: 117
# data 117 shape:  (2047, 40)
# good spectra:  23
# tmp shape:  (23, 2047)
# avg array shape:  (1, 2047)
#
# data index: 118
# data 118 shape:  (2047, 60)
# good spectra:  38
# tmp shape:  (38, 2047)
# avg array shape:  (1, 2047)
#
# data index: 119
# data 119 shape:  (2047, 34)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 120
# data 120 shape:  (2047, 70)
# good spectra:  42
# tmp shape:  (42, 2047)
# avg array shape:  (1, 2047)
#
# data index: 121
# data 121 shape:  (2047, 41)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 122
# data 122 shape:  (2047, 52)
# good spectra:  35
# tmp shape:  (35, 2047)
# avg array shape:  (1, 2047)
#
# data index: 123
# data 123 shape:  (2047, 74)
# good spectra:  40
# tmp shape:  (40, 2047)
# avg array shape:  (1, 2047)
#
# data index: 124
# data 124 shape:  (2047, 67)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 125
# data 125 shape:  (2047, 69)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 126
# data 126 shape:  (2047, 49)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 127
# data 127 shape:  (2047, 52)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 128
# data 128 shape:  (2047, 53)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 129
# data 129 shape:  (2047, 79)
# good spectra:  51
# tmp shape:  (51, 2047)
# avg array shape:  (1, 2047)
#
# data index: 130
# data 130 shape:  (2047, 46)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 131
# data 131 shape:  (2047, 47)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 132
# data 132 shape:  (2047, 67)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 133
# data 133 shape:  (2047, 37)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 134
# data 134 shape:  (2047, 36)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 135
# data 135 shape:  (2047, 48)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 136
# data 136 shape:  (2047, 45)
# good spectra:  38
# tmp shape:  (38, 2047)
# avg array shape:  (1, 2047)
#
# data index: 137
# data 137 shape:  (2047, 45)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 138
# data 138 shape:  (2047, 57)
# good spectra:  23
# tmp shape:  (23, 2047)
# avg array shape:  (1, 2047)
#
# data index: 139
# data 139 shape:  (2047, 50)
# good spectra:  35
# tmp shape:  (35, 2047)
# avg array shape:  (1, 2047)
#
# data index: 140
# data 140 shape:  (2047, 61)
# good spectra:  50
# tmp shape:  (50, 2047)
# avg array shape:  (1, 2047)
#
# data index: 141
# data 141 shape:  (2047, 48)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 142
# data 142 shape:  (2047, 37)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 143
# data 143 shape:  (2047, 67)
# good spectra:  45
# tmp shape:  (45, 2047)
# avg array shape:  (1, 2047)
#
# data index: 144
# data 144 shape:  (2047, 47)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 145
# data 145 shape:  (2047, 35)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 146
# data 146 shape:  (2047, 41)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 147
# data 147 shape:  (2047, 50)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 148
# data 148 shape:  (2047, 36)
# good spectra:  20
# tmp shape:  (20, 2047)
# avg array shape:  (1, 2047)
#
# data index: 149
# data 149 shape:  (2047, 61)
# good spectra:  14
# tmp shape:  (14, 2047)
# avg array shape:  (1, 2047)
#
# data index: 150
# data 150 shape:  (2047, 61)
# good spectra:  52
# tmp shape:  (52, 2047)
# avg array shape:  (1, 2047)
#
# data index: 151
# data 151 shape:  (2047, 34)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 152
# data 152 shape:  (2047, 89)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 153
# data 153 shape:  (2047, 32)
# good spectra:  22
# tmp shape:  (22, 2047)
# avg array shape:  (1, 2047)
#
# data index: 154
# data 154 shape:  (2047, 42)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 155
# data 155 shape:  (2047, 31)
# good spectra:  8
# tmp shape:  (8, 2047)
# avg array shape:  (1, 2047)
#
# data index: 156
# data 156 shape:  (2047, 46)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 157
# data 157 shape:  (2047, 29)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 158
# data 158 shape:  (2047, 35)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 159
# data 159 shape:  (2047, 44)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 160
# data 160 shape:  (2047, 75)
# good spectra:  38
# tmp shape:  (38, 2047)
# avg array shape:  (1, 2047)
#
# data index: 161
# data 161 shape:  (2047, 41)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 162
# data 162 shape:  (2047, 59)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 163
# data 163 shape:  (2047, 33)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 164
# data 164 shape:  (2047, 54)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 165
# data 165 shape:  (2047, 38)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 166
# data 166 shape:  (2047, 53)
# good spectra:  30
# tmp shape:  (30, 2047)
# avg array shape:  (1, 2047)
#
# data index: 167
# data 167 shape:  (2047, 33)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 168
# data 168 shape:  (2047, 35)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 169
# data 169 shape:  (2047, 51)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 170
# data 170 shape:  (2047, 53)
# good spectra:  22
# tmp shape:  (22, 2047)
# avg array shape:  (1, 2047)
#
# data index: 171
# data 171 shape:  (2047, 56)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 172
# data 172 shape:  (2047, 51)
# good spectra:  10
# tmp shape:  (10, 2047)
# avg array shape:  (1, 2047)
#
# data index: 173
# data 173 shape:  (2047, 44)
# good spectra:  35
# tmp shape:  (35, 2047)
# avg array shape:  (1, 2047)
#
# data index: 174
# data 174 shape:  (2047, 48)
# good spectra:  27
# tmp shape:  (27, 2047)
# avg array shape:  (1, 2047)
#
# data index: 175
# data 175 shape:  (2047, 47)
# good spectra:  13
# tmp shape:  (13, 2047)
# avg array shape:  (1, 2047)
#
# data index: 176
# data 176 shape:  (2047, 60)
# good spectra:  39
# tmp shape:  (39, 2047)
# avg array shape:  (1, 2047)
#
# data index: 177
# data 177 shape:  (2047, 67)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 178
# data 178 shape:  (2047, 43)
# good spectra:  38
# tmp shape:  (38, 2047)
# avg array shape:  (1, 2047)
#
# data index: 179
# data 179 shape:  (2047, 57)
# good spectra:  29
# tmp shape:  (29, 2047)
# avg array shape:  (1, 2047)
#
# data index: 180
# data 180 shape:  (2047, 60)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 181
# data 181 shape:  (2047, 42)
# good spectra:  11
# tmp shape:  (11, 2047)
# avg array shape:  (1, 2047)
#
# data index: 182
# data 182 shape:  (2047, 61)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 183
# data 183 shape:  (2047, 52)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 184
# data 184 shape:  (2047, 52)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 185
# data 185 shape:  (2047, 39)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 186
# data 186 shape:  (2047, 56)
# good spectra:  12
# tmp shape:  (12, 2047)
# avg array shape:  (1, 2047)
#
# data index: 187
# data 187 shape:  (2047, 34)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 188
# data 188 shape:  (2047, 48)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 189
# data 189 shape:  (2047, 50)
# good spectra:  39
# tmp shape:  (39, 2047)
# avg array shape:  (1, 2047)
#
# data index: 190
# data 190 shape:  (2047, 50)
# good spectra:  23
# tmp shape:  (23, 2047)
# avg array shape:  (1, 2047)
#
# data index: 191
# data 191 shape:  (2047, 30)
# good spectra:  18
# tmp shape:  (18, 2047)
# avg array shape:  (1, 2047)
#
# data index: 192
# data 192 shape:  (2047, 45)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 193
# data 193 shape:  (2047, 80)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 194
# data 194 shape:  (2047, 67)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 195
# data 195 shape:  (2047, 39)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 196
# data 196 shape:  (2047, 36)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 197
# data 197 shape:  (2047, 37)
# good spectra:  34
# tmp shape:  (34, 2047)
# avg array shape:  (1, 2047)
#
# data index: 198
# data 198 shape:  (2047, 57)
# good spectra:  20
# tmp shape:  (20, 2047)
# avg array shape:  (1, 2047)
#
# data index: 199
# data 199 shape:  (2047, 40)
# good spectra:  14
# tmp shape:  (14, 2047)
# avg array shape:  (1, 2047)
#
# data index: 200
# data 200 shape:  (2047, 86)
# good spectra:  45
# tmp shape:  (45, 2047)
# avg array shape:  (1, 2047)
#
# data index: 201
# data 201 shape:  (2047, 48)
# good spectra:  25
# tmp shape:  (25, 2047)
# avg array shape:  (1, 2047)
#
# data index: 202
# data 202 shape:  (2047, 51)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 203
# data 203 shape:  (2047, 42)
# good spectra:  15
# tmp shape:  (15, 2047)
# avg array shape:  (1, 2047)
#
# data index: 204
# data 204 shape:  (2047, 58)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 205
# data 205 shape:  (2047, 34)
# good spectra:  22
# tmp shape:  (22, 2047)
# avg array shape:  (1, 2047)
#
# data index: 206
# data 206 shape:  (2047, 44)
# good spectra:  26
# tmp shape:  (26, 2047)
# avg array shape:  (1, 2047)
#
# data index: 207
# data 207 shape:  (2047, 59)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 208
# data 208 shape:  (2047, 55)
# good spectra:  31
# tmp shape:  (31, 2047)
# avg array shape:  (1, 2047)
#
# data index: 209
# data 209 shape:  (2047, 57)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 210
# data 210 shape:  (2047, 62)
# good spectra:  32
# tmp shape:  (32, 2047)
# avg array shape:  (1, 2047)
#
# data index: 211
# data 211 shape:  (2047, 40)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 212
# data 212 shape:  (2047, 45)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 213
# data 213 shape:  (2047, 67)
# good spectra:  36
# tmp shape:  (36, 2047)
# avg array shape:  (1, 2047)
#
# data index: 214
# data 214 shape:  (2047, 53)
# good spectra:  3
# tmp shape:  (3, 2047)
# avg array shape:  (1, 2047)
#
# data index: 215
# data 215 shape:  (2047, 53)
# good spectra:  19
# tmp shape:  (19, 2047)
# avg array shape:  (1, 2047)
#
# data index: 216
# data 216 shape:  (2047, 56)
# good spectra:  44
# tmp shape:  (44, 2047)
# avg array shape:  (1, 2047)
#
# data index: 217
# data 217 shape:  (2047, 60)
# good spectra:  46
# tmp shape:  (46, 2047)
# avg array shape:  (1, 2047)
#
# data index: 218
# data 218 shape:  (2047, 64)
# good spectra:  33
# tmp shape:  (33, 2047)
# avg array shape:  (1, 2047)
#
# data index: 219
# data 219 shape:  (2047, 53)
# good spectra:  15
# tmp shape:  (15, 2047)
# avg array shape:  (1, 2047)
#
# data index: 220
# data 220 shape:  (2047, 58)
# good spectra:  28
# tmp shape:  (28, 2047)
# avg array shape:  (1, 2047)
#
# data index: 221
# data 221 shape:  (2047, 51)
# good spectra:  16
# tmp shape:  (16, 2047)
# avg array shape:  (1, 2047)
#
# data index: 222
# data 222 shape:  (2047, 62)
# good spectra:  10
# tmp shape:  (10, 2047)
# avg array shape:  (1, 2047)
#
# data index: 223
# data 223 shape:  (2047, 63)
# good spectra:  15
# tmp shape:  (15, 2047)
# avg array shape:  (1, 2047)
#
# data index: 224
# data 224 shape:  (2047, 61)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 225
# data 225 shape:  (2047, 29)
# good spectra:  3
# tmp shape:  (3, 2047)
# avg array shape:  (1, 2047)
#
# data index: 226
# data 226 shape:  (2047, 59)
# good spectra:  43
# tmp shape:  (43, 2047)
# avg array shape:  (1, 2047)
#
# data index: 227
# data 227 shape:  (2047, 37)
# good spectra:  24
# tmp shape:  (24, 2047)
# avg array shape:  (1, 2047)
#
# data index: 228
# data 228 shape:  (2047, 37)
# good spectra:  8
# tmp shape:  (8, 2047)
# avg array shape:  (1, 2047)
#
# data index: 229
# data 229 shape:  (2047, 29)
# good spectra:  6
# tmp shape:  (6, 2047)
# avg array shape:  (1, 2047)
#
# data index: 230
# data 230 shape:  (2047, 27)
# good spectra:  21
# tmp shape:  (21, 2047)
# avg array shape:  (1, 2047)
#
# data index: 231
# data 231 shape:  (2047, 25)
# good spectra:  17
# tmp shape:  (17, 2047)
# avg array shape:  (1, 2047)
#
# data index: 232
# data 232 shape:  (2047, 38)
# good spectra:  13
# tmp shape:  (13, 2047)
# avg array shape:  (1, 2047)
#
# (233, 2047)

# %%
# %matplotlib notebook
#%matplotlib inline

for i in range(len(tot)):
    #print(i)
    plt.plot(wl, tot[i])
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(wl.shape)
wl1= wl.reshape(1,-1)
print(tot.shape)

a= np.append(wl1, tot, axis=0)
print(a.shape)
print(a)

np.savetxt("ausom_max.csv", a, delimiter=",", fmt='%f')
# Out:
# (2047, 1)
# (233, 2047)
# (234, 2047)
# [[ 1.73738600e+02  1.73868800e+02  1.73999000e+02 ...  4.29601300e+02
#    4.29711600e+02  4.29821800e+02]
#  [ 1.10781522e-03  3.31613082e-03  1.22318522e-04 ... -4.22552299e-03
#   -4.73651958e-03 -3.94833953e-03]
#  [ 7.64730704e-04  2.59357327e-03  3.82014088e-04 ... -2.97496633e-03
#   -3.49239037e-03 -2.67569507e-03]
#  ...
#  [-6.68774198e-02  3.78892797e-03  2.25184005e-03 ... -2.58441673e-03
#   -4.09539084e-03 -2.29517285e-03]
#  [-7.56691698e-02  4.42596862e-03  2.39295987e-03 ... -3.85003497e-03
#   -5.60958858e-03 -4.11086639e-03]
#  [ 9.33538481e-04  2.19756981e-03  5.09969742e-05 ... -2.97098081e-03
#   -4.43044559e-03 -2.46691036e-03]]

# %% [markdown]
# ### Wavelet transform

# %%
import pywt
import pywt.data
#print(pywt.families(short=False))
print(pywt.families(short=True), "\n")
print(pywt.wavelist(kind='discrete'))
# Out:
# ['haar', 'db', 'sym', 'coif', 'bior', 'rbio', 'dmey', 'gaus', 'mexh', 'morl', 'cgau', 'shan', 'fbsp', 'cmor']
#
# ['bior1.1', 'bior1.3', 'bior1.5', 'bior2.2', 'bior2.4', 'bior2.6', 'bior2.8', 'bior3.1', 'bior3.3', 'bior3.5', 'bior3.7', 'bior3.9', 'bior4.4', 'bior5.5', 'bior6.8', 'coif1', 'coif2', 'coif3', 'coif4', 'coif5', 'coif6', 'coif7', 'coif8', 'coif9', 'coif10', 'coif11', 'coif12', 'coif13', 'coif14', 'coif15', 'coif16', 'coif17', 'db1', 'db2', 'db3', 'db4', 'db5', 'db6', 'db7', 'db8', 'db9', 'db10', 'db11', 'db12', 'db13', 'db14', 'db15', 'db16', 'db17', 'db18', 'db19', 'db20', 'db21', 'db22', 'db23', 'db24', 'db25', 'db26', 'db27', 'db28', 'db29', 'db30', 'db31', 'db32', 'db33', 'db34', 'db35', 'db36', 'db37', 'db38', 'dmey', 'haar', 'rbio1.1', 'rbio1.3', 'rbio1.5', 'rbio2.2', 'rbio2.4', 'rbio2.6', 'rbio2.8', 'rbio3.1', 'rbio3.3', 'rbio3.5', 'rbio3.7', 'rbio3.9', 'rbio4.4', 'rbio5.5', 'rbio6.8', 'sym2', 'sym3', 'sym4', 'sym5', 'sym6', 'sym7', 'sym8', 'sym9', 'sym10', 'sym11', 'sym12', 'sym13', 'sym14', 'sym15', 'sym16', 'sym17', 'sym18', 'sym19', 'sym20']

# %%
# %matplotlib notebook


fig, ax = plt.subplots(figsize=(6,1))
ax.set_title("Original Signal: ")
ax.plot(data[:,10])
plt.show()
    
data1 = data[:,10]
print(data1.shape)
waveletname = 'db6'
 
fig, axarr = plt.subplots(nrows=5, ncols=2, figsize=(6,6))
for ii in range(5):
    (data1, coeff_d) = pywt.dwt(data1, waveletname)
    axarr[ii, 0].plot(data1, 'r')
    axarr[ii, 1].plot(coeff_d, 'g')
    axarr[ii, 0].set_ylabel("Level {}".format(ii + 1), fontsize=14, rotation=90)
    axarr[ii, 0].set_yticklabels([])
    if ii == 0:
        axarr[ii, 0].set_title("Approximation coefficients", fontsize=14)
        axarr[ii, 1].set_title("Detail coefficients", fontsize=14)
    axarr[ii, 1].set_yticklabels([])
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="965">
# (3648,)
# <img src="data:image/png;base64,..." width="891">

# %%
a, b =pywt.swt(data1, waveletname, level=2) 

print(type(a))
print(len(a))
print(a[1].shape)
print(type(a[0]))
print(b[1].shape)
print(type(b[0]))

print(type(a))
print(len(a))
print(type(a[1]))
print(type(a[0]))
print(a[0][0].shape)
print(a[0][0])

#plt.plot(wl, a[0][0])
# Out:
# <class 'tuple'>
# 2
# (124,)
# <class 'numpy.ndarray'>
# (124,)
# <class 'numpy.ndarray'>
# <class 'tuple'>
# 2
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ()
# 3371.4281153625648

# %% [markdown]
# - The DWT return two sets of coefficients; the approximation coefficients and detail coefficients.
# - The approximation coefficients represent the output of the low pass filter (averaging filter) of the DWT.
# - The detail coefficients represent the output of the high pass filter (difference filter) of the DWT.
# - By applying the DWT again on the approximation coefficients of the previous DWT, we get the wavelet transform of the next level.
# - At each next level, the original signal is also sampled down by a factor of 2.

# %%
#Is this even useful???

signal = data[:,10]

def lowpassfilter(signal, thresh = 0.63, wavelet="db6"):
#def lowpassfilter(signal, thresh = 0.63, wavelet="db4"):
    thresh = thresh*np.nanmax(signal)
    coeff = pywt.wavedec(signal, wavelet, mode="sp1" )
    coeff[1:] = (pywt.threshold(i, value=thresh, mode="soft" ) for i in coeff[1:])
    reconstructed_signal = pywt.waverec(coeff, wavelet, mode="sp1" )
    return reconstructed_signal
 
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(signal, color="b", alpha=0.5, label='original signal')
rec = lowpassfilter(signal, 0.4)
ax.plot(rec, 'k', label='DWT smoothing', linewidth=2)
ax.legend()
ax.set_title('Removing High Frequency Noise with DWT', fontsize=18)
ax.set_ylabel('Signal Amplitude', fontsize=16)
ax.set_xlabel('Sample No', fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# # Normalization

# %%
data[0,:]
# Out:
# array([4834., 4823., 4700., ..., 4533., 4572., 4599.])

# %%
a= normalize(data[0,:].reshape(1, -1))
a.shape
# Out:
# (1, 1446)

# %%
print(wl.shape)
print(a.shape)
# Out:
# (1446,)
# (1, 1446)

# %%
# %matplotlib inline
plt.plot(wl, a.T)
plt.show()

# %%
tmp=normalize(data)
print(wl.shape)
print(tmp.shape)


# %matplotlib inline
for i in range(len(tmp)):
    plt.plot(wl, tmp[i,:])
    #plt.show()
# Out:
# (1446,)
# (100, 1446)

# %%
print(wl.shape)
print(len(wl))
# Out:
# (1446,)
# 1446

# %%
tot= np.empty((0, len(wl)))


for j in range(0, len(dfs)):
    data = dfs[j].values
    data = data[1:,:]
    print("data index: " + str(j))
    print("data " + str(j) + " shape: ", data.shape)
    
    count=0

    #result_array = np.empty_like(wl)
    
    tmp = np.empty((0, len(wl)))

    
    for i in (range(len(data)) ):
    
        z_i = baseline_als(data[i,:], lam, p, niter=10)

        a = data[i,:] - z_i


        if (max(a)) > 25000:

            #a =  a / np.sum(a,axis=0)
            #a = StandardScaler().fit_transform(a.reshape(-1, 1))
            #a= normalize(a.reshape(-1, 1))

            count += 1
            #print(i)
            #plt.plot(wl, a)
            #plt.show()
            tmp = np.append(tmp, [a], axis=0)
    
    """
    for i in (range(len(data[0])) ):
        
        z_i = baseline_als(data[:,i], lam, p, niter=10)

        a = data[:,i] - z_i    
        
    
        if ((max(a)) > 2000): # and ((max(data[:,i])) < 65500):
        #if ((max(data[:,i])) > 10000):
            count += 1
            #print(i)
            #plt.plot(wl, data[:,i])
            #plt.show()
            tmp = np.append(tmp, [a], axis=0)
    """

    print("good spectra: ", count)
    print("tmp shape: ", tmp.shape)

    avg_arr= np.mean(tmp, axis=0).reshape((1, -1))
    #avg_arr= np.max(tmp, axis=0).reshape((1, -1))
    print("avg array shape: " , avg_arr.shape)
    print("")
    
    
    tot = np.append(tot, avg_arr, axis=0)

print(tot.shape)

# %%
for i in range(len(tot)):
    plt.plot(wl, tot[i])
    #plt.show()

# %%
print(tot.shape)
print(wl.shape)

# %%
print(wl.shape)
wl= wl.reshape(1,-1)
print(tot.shape)

a= np.append(wl, tot, axis=0)
print(a.shape)
print(a)

# %%
#np.savetxt("avg_intesities_baseline_1.csv", a, delimiter=",", fmt='%f')

# %%
X_std = StandardScaler().fit_transform(data)
print(X_std.shape)
X_std

# %%
data_sum= data / np.sum(data,axis=0)
data_sum

# %%
for i in (range(len(X_std[0]))):
    
    plt.plot(wl, X_std[:,i] )
    plt.show()

# %%
print(max(data[:,8]))
print(max(data[:,11]))
max(data[:,1])

# %%
count = 0
for i in (range(len(data[0])) ):
    
    z_i = baseline_als(data[:,i], lam, p, niter=10)
    
    a = data[:,i] - z_i
    
    #a=  a / np.sum(a,axis=0)
    #a=  a / np.max(a,axis=0)


    count += 1
    #print(i)
    plt.plot(wl, a)
    #plt.show()
print("good spectra: ", count)

# %%
count = 0
for i in (range(len(data[0])) ):
    
    z_i = baseline_als(data[600:1730,i], lam, p, niter=10)
    
    a = data[600:1730,i] - z_i
    
    
    if (max(a)) > 25000:
        
        a =  a / np.sum(a,axis=0)
        #a = StandardScaler().fit_transform(a.reshape(-1, 1))
        #a= normalize(a.reshape(-1, 1))
        
        count += 1
        #print(i)
        plt.plot(wl[600:1730], a)
        plt.show()
        #plt.savefig('./graph.png')
print("good spectra: ", count)

# %%
count=0

#result_array = np.empty_like(wl)
tmp = np.empty((0, len(wl)))

for i in (range(len(data[0])) ):
    
    z_i = baseline_als(data[:,i], lam, p, niter=10)
    
    if ((max(data[:,i]-z_i)) > 10000) and ((max(data[:,i])) < 65500):
        count += 1
        #print(i)
        plt.plot(wl, data[:,i])
        #plt.show()
        tmp = np.append(tmp, [data[:,i]], axis=0)
        
        
print("good spectra: ", count)
print(tmp.shape)

avg_arr= np.max(tmp, axis=0)
#avg_arr= np.mean(tmp, axis=0)
print(avg_arr.shape)

# %%
count=0

#result_array = np.empty_like(wl)
tmp = np.empty((0, len(wl)))

for i in (range(len(data[0])) ):
    if ((max(data[:,i])) > 10000) and ((max(data[:,i])) < 65500):
        count += 1
        #print(i)
        plt.plot(wl, data[:,i])
        #plt.show()
        result_array = np.append(tmp, [data[:,i]], axis=0)
        
        
print("good spectra: ", count)
print(tmp.shape)

avg_arr= np.mean(tmp, axis=0)
print(avg_arr.shape)

# %%
plt.plot(wl, avg_arr)
plt.show()

# %%
good = np.empty([len(wl)])

good1 = np.empty_like(wl)

print(good.shape)
print(good1.shape)

# %%
print(result_array.shape)
print(result_array)
a=np.mean(result_array, axis=0)
print(a.shape)

# %%
"""from glob import glob

#filenames = glob('./ref/*')
filenames = glob('./ref_1/*')


dfs = [scipy.io.loadmat(f) for f in filenames]
print(type(dfs)) #dfs is a list of mat files 
print(len(dfs)) #dfs is a list of mat files 
"""

# %%
tot= np.empty((0, len(wl)))


for j in range(0, len(dfs)): #loop over all .mat files
    mat = dfs[j]
    data = mat["data"]
    print("data index: " + str(j))
    print("data " + str(j) + " shape: ", data.shape)
    
    count=0

    #result_array = np.empty_like(wl)
    
    tmp = np.empty((0, len(wl)))

    for i in (range(len(data[0])) ):
        
        
    
        if ((max(data[:,i])) > 10000) and ((max(data[:,i])) < 65500):
        #if ((max(data[:,i])) > 10000):
            count += 1
            #print(i)
            #plt.plot(wl, data[:,i])
            #plt.show()
            tmp = np.append(tmp, [data[:,i]], axis=0)


    print("good spectra: ", count)
    print("tmp shape: ", tmp.shape)

    #avg_arr= np.mean(tmp, axis=0).reshape((1, -1))
    avg_arr= np.max(tmp, axis=0).reshape((1, -1))
    print("avg array shape: " , avg_arr.shape)
    print("")
    
    
    tot = np.append(tot, avg_arr, axis=0)

print(tot.shape)

# %% [markdown]
# WITH BASELINE CORRECTION

# %%
tot= np.empty((0, len(wl[600:1730])))


for j in range(0, len(dfs)): #loop over all .mat files
    mat = dfs[j]
    data = mat["data"]
    print("data index: " + str(j))
    print("data " + str(j) + " shape: ", data.shape)
    
    count=0

    #result_array = np.empty_like(wl)
    
    tmp = np.empty((0, len(wl[600:1730])))

    
    for i in (range(len(data[0])) ):
    
        z_i = baseline_als(data[600:1730,i], lam, p, niter=10)

        a = data[600:1730,i] - z_i


        if (max(a)) > 25000:

            a =  a / np.sum(a,axis=0)
            #a = StandardScaler().fit_transform(a.reshape(-1, 1))
            #a= normalize(a.reshape(-1, 1))

            count += 1
            #print(i)
            plt.plot(wl[600:1730], a)
            plt.show()
            tmp = np.append(tmp, [a], axis=0)
    
    """
    for i in (range(len(data[0])) ):
        
        z_i = baseline_als(data[:,i], lam, p, niter=10)

        a = data[:,i] - z_i    
        
    
        if ((max(a)) > 2000): # and ((max(data[:,i])) < 65500):
        #if ((max(data[:,i])) > 10000):
            count += 1
            #print(i)
            #plt.plot(wl, data[:,i])
            #plt.show()
            tmp = np.append(tmp, [a], axis=0)
    """

    print("good spectra: ", count)
    print("tmp shape: ", tmp.shape)

    avg_arr= np.mean(tmp, axis=0).reshape((1, -1))
    #avg_arr= np.max(tmp, axis=0).reshape((1, -1))
    print("avg array shape: " , avg_arr.shape)
    print("")
    
    
    tot = np.append(tot, avg_arr, axis=0)

print(tot.shape)

# %%
tot= np.empty((0, len(wl[600:1730])))


for j in range(0, len(dfs)): #loop over all .mat files
    mat = dfs[j]
    data = mat["data"]
    print("data index: " + str(j))
    print("data " + str(j) + " shape: ", data.shape)
    
    count=0

    #result_array = np.empty_like(wl)
    
    tmp = np.empty((0, len(wl[600:1730])))

    
    for i in (range(len(data[0])) ):
        if (max(data[:,i])) > 25000:
            
            
            z_i = baseline_als(data[600:1730,i], lam, p, niter=10)

            a = data[600:1730,i] - z_i


        

            a =  a / np.sum(a,axis=0)
            #a = StandardScaler().fit_transform(a.reshape(-1, 1))
            #a= normalize(a.reshape(-1, 1))

            count += 1
            #print(i)
            #plt.plot(wl[600:1730], a)
            #plt.show()
            tmp = np.append(tmp, [a], axis=0)
    
    """
    for i in (range(len(data[0])) ):
        
        z_i = baseline_als(data[:,i], lam, p, niter=10)

        a = data[:,i] - z_i    
        
    
        if ((max(a)) > 2000): # and ((max(data[:,i])) < 65500):
        #if ((max(data[:,i])) > 10000):
            count += 1
            #print(i)
            #plt.plot(wl, data[:,i])
            #plt.show()
            tmp = np.append(tmp, [a], axis=0)
    """

    print("good spectra: ", count)
    print("tmp shape: ", tmp.shape)

    avg_arr= np.mean(tmp, axis=0).reshape((1, -1))
    #avg_arr= np.max(tmp, axis=0).reshape((1, -1))
    print("avg array shape: " , avg_arr.shape)
    print("")
    
    
    tot = np.append(tot, avg_arr, axis=0)

print(tot.shape)

# %%
for i in range(len(tot)):
    plt.plot(wl[600:1730], tot[i])
    #plt.show()

# %%
ded #np.savetxt("avg_intesities.csv", tot, delimiter=",", fmt='%f')

# %%
print(wl.shape)
wl1= wl[600:1730].reshape(1,-1)
print(tot.shape)

a= np.append(wl1, tot, axis=0)
a.shape
a

# %%
#np.savetxt("avg_intesities_baseline_1.csv", a, delimiter=",", fmt='%f')
